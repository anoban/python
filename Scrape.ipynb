# %%
from bs4 import BeautifulSoup
from urllib import request
import numpy as np
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# %%
with request.urlopen("https://www.police.lk/?page_id=3370") as opener:
    text = opener.read()

# %%
soup = BeautifulSoup(text, "html.parser")

# %%
soup.find_all("table") #, attrs = {"Class": "ninja_table_row_27"})
# Out:
# [<table aria-label="police_telephone_index.csv" class="foo-table ninja_footable foo_table_3659 ninja_table_unique_id_1457992019_3659 ui table nt_type_ajax_table selectable striped vertical_centered footable-paging-right ninja_table_pro" data-filter-delay="1000" data-footable_id="3659" data-ninja_table_instance="ninja_table_instance_0" data-unique_identifier="ninja_table_unique_id_1457992019_3659" id="footable_3659">
#  <colgroup>
#  <col class="ninja_column_0"/>
#  <col class="ninja_column_1"/>
#  <col class="ninja_column_2"/>
#  <col class="ninja_column_3"/>
#  <col class="ninja_column_4"/>
#  </colgroup>
#  </table>]

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en-US">
# <head>
# <meta charset="utf-8"/>
# <link href="http://gmpg.org/xfn/11" rel="profile"/>
# <link href="https://www.police.lk/xmlrpc.php" rel="pingback"/>
# <title>Telephone Index – Sri Lanka Police</title>
# <meta content="max-image-preview:large" name="robots">
# <link href="//fonts.googleapis.com" rel="dns-prefetch">
# <link href="//s.w.org" rel="dns-prefetch">
# <link href="https://www.police.lk/?feed=rss2" rel="alternate" title="Sri Lanka Police » Feed" type="application/rss+xml"/>
# <link href="https://www.police.lk/?feed=comments-rss2" rel="alternate" title="Sri Lanka Police » Comments Feed" type="application/rss+xml"/>
# <link href="https://www.police.lk/wp-content/uploads/blocksy/css/global.css?ver=94118" id="blocksy-dynamic-global-css" media="all" rel="stylesheet"/>
# <link href="https://www.police.lk/wp-includes/css/dist/block-library/style.min.css?ver=6.0.1" id="wp-block-library-css" media="all" rel="stylesheet"/>
# <style id="global-styles-inline-css">
# body{--wp--preset--color--black: #000000;--wp--preset--color--cyan-bluish-gray: #abb8c3;--wp--preset--color--white: #ffffff;--wp--preset--color--pale-pink: #f78da7;--wp--preset--color--vivid-red: #cf2e2e;--wp--preset--color--luminous-vivid-orange: #ff6900;--wp--preset--color--luminous-vivid-amber: #fcb900;--wp--preset--color--light-green-cyan: #7bdcb5;--wp--preset--color--vivid-green-cyan: #00d084;--wp--preset--color--pale-cyan-blue: #8ed1fc;--wp--preset--color--vivid-cyan-blue: #0693e3;--wp--preset--color--vivid-purple: #9b51e0;--wp--preset--color--palette-color-1: var(--paletteColor1, #4D5D6D);--wp--preset--color--palette-color-2: var(--paletteColor2, #2B286D);--wp--preset--color--palette-color-3: var(--paletteColor3, #4d5d6d);--wp--preset--color--palette-color-4: var(--paletteColor4, #102136);--wp--preset--color--palette-color-5: var(--paletteColor5, #E7EBEE);--wp--preset--color--palette-color-6: var(--paletteColor6, #F3F5F7);--wp--preset--color--palette-color-7: var(--paletteColor7, #FBFBFC);--wp--preset--color--palette-color-8: var(--paletteColor8, #ffffff);--wp--preset--gradient--vivid-cyan-blue-to-vivid-purple: linear-gradient(135deg,rgba(6,147,227,1) 0%,rgb(155,81,224) 100%);--wp--preset--gradient--light-green-cyan-to-vivid-green-cyan: linear-gradient(135deg,rgb(122,220,180) 0%,rgb(0,208,130) 100%);--wp--preset--gradient--luminous-vivid-amber-to-luminous-vivid-orange: linear-gradient(135deg,rgba(252,185,0,1) 0%,rgba(255,105,0,1) 100%);--wp--preset--gradient--luminous-vivid-orange-to-vivid-red: linear-gradient(135deg,rgba(255,105,0,1) 0%,rgb(207,46,46) 100%);--wp--preset--gradient--very-light-gray-to-cyan-bluish-gray: linear-gradient(135deg,rgb(238,238,238) 0%,rgb(169,184,195) 100%);--wp--preset--gradient--cool-to-warm-spectrum: linear-gradient(135deg,rgb(74,234,220) 0%,rgb(151,120,209) 20%,rgb(207,42,186) 40%,rgb(238,44,130) 60%,rgb(251,105,98) 80%,rgb(254,248,76) 100%);--wp--preset--gradient--blush-light-purple: linear-gradient(135deg,rgb(255,206,236) 0%,rgb(152,150,240) 100%);--wp--preset--gradient--blush-bordeaux: linear-gradient(135deg,rgb(254,205,165) 0%,rgb(254,45,45) 50%,rgb(107,0,62) 100%);--wp--preset--gradient--luminous-dusk: linear-gradient(135deg,rgb(255,203,112) 0%,rgb(199,81,192) 50%,rgb(65,88,208) 100%);--wp--preset--gradient--pale-ocean: linear-gradient(135deg,rgb(255,245,203) 0%,rgb(182,227,212) 50%,rgb(51,167,181) 100%);--wp--preset--gradient--electric-grass: linear-gradient(135deg,rgb(202,248,128) 0%,rgb(113,206,126) 100%);--wp--preset--gradient--midnight: linear-gradient(135deg,rgb(2,3,129) 0%,rgb(40,116,252) 100%);--wp--preset--gradient--juicy-peach: linear-gradient(to right, #ffecd2 0%, #fcb69f 100%);--wp--preset--gradient--young-passion: linear-gradient(to right, #ff8177 0%, #ff867a 0%, #ff8c7f 21%, #f99185 52%, #cf556c 78%, #b12a5b 100%);--wp--preset--gradient--true-sunset: linear-gradient(to right, #fa709a 0%, #fee140 100%);--wp--preset--gradient--morpheus-den: linear-gradient(to top, #30cfd0 0%, #330867 100%);--wp--preset--gradient--plum-plate: linear-gradient(135deg, #667eea 0%, #764ba2 100%);--wp--preset--gradient--aqua-splash: linear-gradient(15deg, #13547a 0%, #80d0c7 100%);--wp--preset--gradient--love-kiss: linear-gradient(to top, #ff0844 0%, #ffb199 100%);--wp--preset--gradient--new-retrowave: linear-gradient(to top, #3b41c5 0%, #a981bb 49%, #ffc8a9 100%);--wp--preset--gradient--plum-bath: linear-gradient(to top, #cc208e 0%, #6713d2 100%);--wp--preset--gradient--high-flight: linear-gradient(to right, #0acffe 0%, #495aff 100%);--wp--preset--gradient--teen-party: linear-gradient(-225deg, #FF057C 0%, #8D0B93 50%, #321575 100%);--wp--preset--gradient--fabled-sunset: linear-gradient(-225deg, #231557 0%, #44107A 29%, #FF1361 67%, #FFF800 100%);--wp--preset--gradient--arielle-smile: radial-gradient(circle 248px at center, #16d9e3 0%, #30c7ec 47%, #46aef7 100%);--wp--preset--gradient--itmeo-branding: linear-gradient(180deg, #2af598 0%, #009efd 100%);--wp--preset--gradient--deep-blue: linear-grad ...
# </style>
# <link href="https://www.police.lk/wp-content/themes/blocksy/style.css?ver=6.0.1" id="parent-style-css" media="all" rel="stylesheet"/>
# <link href="https://www.police.lk/wp-content/themes/blocksy/static/bundle/main.min.css?ver=1.8.46" id="ct-main-styles-css" media="all" rel="stylesheet"/>
# <link href="https://www.police.lk/wp-content/plugins/blocksy-companion-pro/framework/extensions/widgets/static/bundle/main.min.css?ver=1.8.46" id="blocksy-ext-widgets-styles-css" media="all" rel="stylesheet"/>
# <link href="https://www.police.lk/wp-content/plugins/blocksy-companion-pro/framework/extensions/cookies-consent/static/bundle/main.min.css?ver=1.8.46" id="blocksy-ext-cookies-consent-styles-css" media="all" rel="stylesheet"/>
# <link href="https://fonts.googleapis.com/css2?family=Source%20Sans%20Pro:wght@400;500;600;700&amp;display=swap" id="blocksy-fonts-font-source-google-css" media="all" rel="stylesheet"/>
# <link href="https://www.police.lk/wp-content/themes/blocksy/static/bundle/page-title.min.css?ver=1.8.46" id="ct-page-title-styles-css" media="all" rel="stylesheet"/>
# <link href="https://www.police.lk/wp-content/themes/blocksy/static/bundle/brizy.min.css?ver=1.8.46" id="ct-brizy-styles-css" media="all" rel="stylesheet"/>
# <link href="https://www.police.lk/wp-content/plugins/ninja-tables/assets/css/ninjatables-public.css?ver=4.2.3" id="footable_styles-css" media="all" rel="stylesheet"/>
# <link href="https://www.police.lk/wp-content/plugins/youtube-embed-plus/styles/ytprefs.min.css?ver=14.1.2" id="__EPYT__style-css" media="all" rel="stylesheet"/>
# <style id="__EPYT__style-inline-css">
#
#                 .epyt-gallery-thumb {
#                         width: 33.333%;
#                 }
#
# </style>
# <link class="brz-link brz-link-google" href="https://fonts.googleapis.com/css?family=Source+Sans+Pro%3A200%2C200italic%2C300%2C300italic%2Cregular%2Citalic%2C600%2C600italic%2C700%2C700italic%2C900%2C900italic%7CLibre+Baskerville%3Aregular%2Citalic%2C700%7CLato%3A100%2C100italic%2C300%2C300italic%2Cregular%2Citalic%2C700%2C700italic%2C900%2C900italic&amp;subset=arabic%2Cbengali%2Ccyrillic%2Ccyrillic-ext%2Cdevanagari%2Cgreek%2Cgreek-ext%2Cgujarati%2Chebrew%2Ckhmer%2Ckorean%2Clatin-ext%2Ctamil%2Ctelugu%2Cthai%2Cvietnamese&amp;display=swap&amp;ver=2.4.5" id="brizy-asset-google-10-css" media="all" rel="stylesheet" type="text/css"/>
# <link class="brz-link brz-link-preview-lib-pro" data-group="group-2" href="https://www.police.lk/wp-content/plugins/brizy-pro/public/editor-build/116-wp/css/group-2-pro.css?ver=2.4.6" id="brizy-asset-group-2-21-css" media="all" rel="stylesheet"/>
# <link class="brz-link brz-link-preview-pro" href="https://www.police.lk/wp-content/plugins/brizy-pro/public/editor-build/116-wp/css/preview.pro.css?ver=2.4.6" id="brizy-asset-main-30-css" media="all" rel="stylesheet"/>
# <style id="brizy-asset-main-30-inline-css">
# .brz .brz-cp-color1, .brz .brz-bcp-color1{color: #4d5d6d;}.brz .brz-cp-color2, .brz .brz-bcp-color2{color: #2b286d;}.brz .brz-cp-color3, .brz .brz-bcp-color3{color: #2b286d;}.brz .brz-cp-color4, .brz .brz-bcp-color4{color: #2b286d;}.brz .brz-cp-color5, .brz .brz-bcp-color5{color: #1c13e2;}.brz .brz-cp-color6, .brz .brz-bcp-color6{color: #f5f5f5;}.brz .brz-cp-color7, .brz .brz-bcp-color7{color: #4d5d6d;}.brz .brz-cp-color8, .brz .brz-bcp-color8{color: #FFFFFF;}:root{--brz-global-color1:77, 93, 109;--brz-global-color2:43, 40, 109;--brz-global-color3:43, 40, 109;--brz-global-color4:43, 40, 109;--brz-global-color5:28, 19, 226;--brz-global-color6:245, 245, 245;--brz-global-color7:77, 93, 109;--brz-global-color8:255, 255, 255;}:root{
#       --brz-paragraphfontfamily: Source Sans Pro, sans-serif;
#       --brz-paragraphfontsize: 16px;
#       --brz-paragraphfontsizesuffix: undefined;
#       --brz-paragraphfontweight: 400;
#       --brz-paragraphletterspacing: 0.5px;
#       --brz-paragraphlineheight: 1.7;
#
#       --brz-paragraphtabletfontsize: 15px;
#       --brz-paragraphtabletfontweight: 400;
#       --brz-paragraphtabletletterspacing: 0px;
#       --brz-paragraphtabletlineheight: 1.6;
#
#       --brz-paragraphmobilefontsize: 15px;
#       --brz-paragraphmobilefontweight: 400;
#       --brz-paragraphmobileletterspacing: 0px;
#       --brz-paragraphmobilelineheight: 1.6;
#
#       --brz-paragraphstoryfontsize: 3.68%;
#
#       --brz-subtitlefontfamily: Libre Baskerville, serif;
#       --brz-subtitlefontsize: 17px;
#       --brz-subtitlefontsizesuffix: px;
#       --brz-subtitlefontweight: 400;
#       --brz-subtitleletterspacing: 0px;
#       --brz-subtitlelineheight: 1.7;
#
#       --brz-subtitletabletfontsize: 17px;
#       --brz-subtitletabletfontweight: 400;
#       --brz-subtitletabletletterspacing: 0px;
#       --brz-subtitletabletlineheight: 1.7;
#
#       --brz-subtitlemobilefontsize: 16px;
#       --brz-subtitlemobilefontweight: 400;
#       --brz-subtitlemobileletterspacing: 0px;
#       --brz-subtitlemobilelineheight: 1.6;
#
#       --brz-subtitlestoryfontsize: 3.91%;
#
#       --brz-abovetitlefontfamily: Source Sans Pro, sans-serif;
#       --brz-abovetitlefontsize: 18px;
#       --brz-abovetitlefontsizesuffix: px;
#       --brz-abovetitlefontweight: 700;
#       --brz-abovetitleletterspacing: 0px;
#       --brz-abovetitlelineheight: 1.2;
#
#       --brz-abovetitletabletfontsize: 17px;
#       --brz-abovetitletabletfontweight: 700;
#       --brz-abovetitletabletletterspacing: 1px;
#       --brz-abovetitletabletlineheight: 1.2;
#
#       --brz-abovetitlemobilefontsize: 14px;
#       --brz-abovetitlemobilefontweight: 700;
#       --brz-abovetitlemobileletterspacing: 1px;
#       --brz-abovetitlemobilelineheight: 1.2;
#
#       --brz-abovetitlestoryfontsize: 4.140000000000001%;
#
#       --brz-heading1fontfamily: Libre Baskerville, serif;
#       --brz-heading1fontsize: 48px;
#       --brz-heading1fontsizesuffix: px;
#       --brz-heading1fontweight: 800;
#       --brz-heading1letterspacing: 0px;
#       --brz-heading1lineheight: 1.2;
#
#       --brz-heading1tabletfontsize: 41px;
#       --brz-heading1tabletfontweight: 800;
#       --brz-heading1tabletletterspacing: -1px;
#       --brz-heading1tabletlineheight: 1.2;
#
#       --brz-heading1mobilefontsize: 38px;
#       --brz-heading1mobilefontweight: 800;
#       --brz-heading1mobileletterspacing: -1px;
#       --brz-heading1mobilelineheight: 1.2;
#
#       --brz-heading1storyfontsize: 11.040000000000001%;
#
#       --brz-heading2fontfamily: Libre Baskerville, serif;
#       --brz-heading2fontsize: 38px;
#       --brz-heading2fontsizesuffix: px;
#       --brz-heading2fontweight: 800;
#       --brz-heading2letterspacing: 1px;
#       --brz-heading2lineheight: 1.3;
#
#       --brz-heading2tabletfontsize: 33px;
#       --brz-heading2tabletfontweight: 800;
#       --brz-heading2tabletletterspacing: -1px;
#       --brz-heading2tabletlineheight: 1.3;
#
#       --brz-heading2mobilefontsize: 30px;
#       --brz-heading2mobilefontweight: 800;
#       --brz-heading2mobileletterspacing: -1px;
#       --brz-heading2mobilelineheight: 1.3;
#
#       --brz-heading2storyfontsize: 8.74%;
#
#       --brz-heading3fontfamily: Libre Baskerville, serif;
#       --brz-heading3fontsize: 33px;
#       --brz-heading3fontsizesuffix: px;
#       --brz-heading3fontweight: 800;
#       --brz-heading3letterspacing: 1px;
#       --brz-heading3lineheight: 1.3;
#
#       --brz-heading3tabletfontsize: 30px;
#       --brz-heading3tabletfontweight: 800;
#       --brz-heading3tabletletterspacing: -1px;
#       --brz-heading3tabletlineheight: 1.3;
#
#       --brz-heading3mobilefontsize: 27px;
#       --brz-heading3mobilefontweight: 800;
#       --brz-heading3mobileletterspacing: -1px;
#       --brz-heading3mobilelineheight: 1.3;
#
#       --brz-heading3storyfontsize: 7.590000000000001%;
#
#       --brz-heading4fontfamily: Libre Baskerville, serif;
#       --brz-heading4fontsize: 27px;
#       --brz-heading4fontsizesuffix: px;
#       --brz-heading4fontweight: 700;
#       --brz-heading4letterspacing: 1px;
#       --brz-heading4lineheight: 1.4;
#
#       --brz-heading4tabletfontsize: 26px;
#       --brz-heading4tabletfontweight: 700;
#       --brz-heading4tabletletterspacing: -1px;
#       --brz-heading4tabletlineheight: 1.4;
#
#       --brz-heading4mobilefontsize: 24px;
#       --brz-heading4mobilefontweight: 700;
#       --brz-heading4mobileletterspacing: -1px;
#       --brz-heading4mobilelineheight: 1.4;
#
#       --brz-heading4storyfontsize: 6.21%;
#
#       --brz-heading5fontfamily: Source Sans Pro, sans-serif;
#       --brz-heading5fontsize: 22px;
#       --brz-heading5fontsizesuffix: px;
#       --brz-heading5fontweight: 700;
#       --brz-heading5letterspacing: 1px;
#       --brz-heading5lineheight: 1.5;
#
#       --brz-heading5tabletfontsize: 20px;
#       --brz-heading5tabletfontweight: 700;
#       --brz-heading5tabletletterspacing: -1px;
#       --brz-heading5tabletlineheight: 1.5;
#
#       --brz-heading5mobilefontsize: 18px;
#       --brz-heading5mobilefontweight: 700;
#       --brz-heading5mobileletterspacing: -1px;
#       --brz-heading5mobilelineheight: 1.5;
#
#       --brz-heading5storyfontsize: 5.0600000000000005%;
#
#       --brz-heading6fontfamily: Source Sans Pro, sans-serif;
#       --brz-heading6fontsize: 20px;
#       --brz-heading6fontsizesuffix: px;
#       --brz-heading6fontweight: 600;
#       --brz-heading6letterspacing: 1px;
#       --brz-heading6lineheight: 1.5;
#
#       --brz-heading6tabletfontsize: 19px;
#       --brz-heading6tabletfontweight: 400;
#       --brz-heading6tabletletterspacing: -1px;
#       --brz-heading6tabletlineheight: 1.5;
#
#       --brz-heading6mobilefontsize: 17px;
#       --brz-heading6mobilefontweight: 400;
#       --brz-heading6mobileletterspacing: -1px;
#       --brz-heading6mobilelineheight: 1.4;
#
#       --brz-heading6storyfontsize: 4.6000000000000005%;
#
#       --brz-buttonfontfamily: Source Sans Pro, sans-serif;
#       --brz-buttonfontsize: 16px;
#       --brz-buttonfontsizesuffix: px;
#       --brz-buttonfontweight: 600;
#       --brz-buttonletterspacing: 0px;
#       --brz-buttonlineheight: 1.3;
#
#       --brz-buttontabletfontsize: 16px;
#       --brz-buttontabletfontweight: 400;
#       --brz-buttontabletletterspacing: 0px;
#       --brz-buttontabletlineheight: 1.3;
#
#       --brz-buttonmobilefontsize: 16px;
#       --brz-buttonmobilefontweight: 400;
#       --brz-buttonmobileletterspacing: 0px;
#       --brz-buttonmobilelineheight: 1.3;
#
#       --brz-buttonstoryfontsize: 3.68%;
#       }
# </style>
# <script id="jquery-core-js" src="https://www.police.lk/wp-includes/js/jquery/jquery.min.js?ver=3.6.0"></script>
# <script id="jquery-migrate-js" src="https://www.police.lk/wp-includes/js/jquery/jquery-migrate.min.js?ver=3.3.2"></script>
# <script id="__ytprefs__-js-extra">
# var _EPYT_ = {"ajaxurl":"https:\/\/www.police.lk\/wp-admin\/admin-ajax.php","security":"c9763efa97","gallery_scrolloffset":"20","eppathtoscripts":"https:\/\/www.police.lk\/wp-content\/plugins\/youtube-embed-plus\/scripts\/","eppath":"https:\/\/www.police.lk\/wp-content\/plugins\/youtube-embed-plus\/","epresponsiveselector":"[\"iframe.__youtube_prefs__\",\"iframe[src*='youtube.com']\",\"iframe[src*='youtube-nocookie.com']\",\"iframe[data-ep-src*='youtube.com']\",\"iframe[data-ep-src*='youtube-nocookie.com']\",\"iframe[data-ep-gallerysrc*='youtube.com']\"]","epdovol":"1","version":"14.1.2","evselector":"iframe.__youtube_prefs__[src], iframe[src*=\"youtube.com\/embed\/\"], iframe[src*=\"youtube-nocookie.com\/embed\/\"]","ajax_compat":"","ytapi_load":"light","pause_others":"","stopMobileBuffer":"1","facade_mode":"","not_live_on_channel":"","vi_active":"","vi_js_posttypes":[]};
# </script>
# <script id="__ytprefs__-js" src="https://www.police.lk/wp-content/plugins/youtube-embed-plus/scripts/ytprefs.min.js?ver=14.1.2"></script>
# <script id="brizy-preview-js-before">
# var __CONFIG__ = {"serverTimestamp":1686364807,"currentUser":{"user_login":false,"user_email":false,"user_level":false,"user_firstname":false,"user_lastname":false,"display_name":false,"ID":0,"roles":[]}};
# </script>
# <link href="https://www.police.lk/index.php?rest_route=/" rel="https://api.w.org/"/><link href="https://www.police.lk/index.php?rest_route=/wp/v2/pages/3370" rel="alternate" type="application/json"/><link href="https://www.police.lk/xmlrpc.php?rsd" rel="EditURI" title="RSD" type="application/rsd+xml"/>
# <link href="https://www.police.lk/wp-includes/wlwmanifest.xml" rel="wlwmanifest" type="application/wlwmanifest+xml"/>
# <meta content="WordPress 6.0.1" name="generator"/>
# <link href="https://www.police.lk/?page_id=3370" rel="canonical"/>
# <link href="https://www.police.lk/?p=3370" rel="shortlink"/>
# <link href="https://www.police.lk/index.php?rest_route=%2Foembed%2F1.0%2Fembed&amp;url=https%3A%2F%2Fwww.police.lk%2F%3Fpage_id%3D3370" rel="alternate" type="application/json+oembed"/>
# <link href="https://www.police.lk/index.php?rest_route=%2Foembed%2F1.0%2Fembed&amp;url=https%3A%2F%2Fwww.police.lk%2F%3Fpage_id%3D3370&amp;format=xml" rel="alternate" type="text/xml+oembed"/>
# <!-- Google tag (gtag.js) -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-155057230-1"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'UA-155057230-1');
# </script>
# <noscript><link href="https://www.police.lk/wp-content/themes/blocksy/static/bundle/no-scripts.min.css" rel="stylesheet" type="text/css"/></noscript>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link class="brz-link brz-link-google-prefetch" href="//ajax.googleapis.com" rel="dns-prefetch"/> <link class="brz-link brz-link-google-prefetch" href="//fonts.googleapis.com" rel="dns-prefetch"/> <link class="brz-link brz-link-google-preconnect" crossorigin="" href="https://fonts.gstatic.com/" rel="preconnect"/>
# <style class="brz-style">.brz .css-njl3kp,.brz [data-css-njl3kp]{color:rgba(var(--brz-global-color8),1);border-color:rgba(var(--brz-global-color8),1);background-color:rgba(var(--brz-global-color5),1);background-image:none;border-width:1px;border-style:solid;width:46px;height:46px;font-size:24px;padding:10px;border-radius:25px;stroke-width:0;transition:all 0.50s ease-in-out;transition-property:background, border-radius, color, border-color, box-shadow;-webkit-transition:all 0.50s ease-in-out;-moz-transition:all 0.50s ease-in-out;-webkit-transition-property:background, border-radius, color, border-color, box-shadow;-moz-transition-property:background, border-radius, color, border-color, box-shadow;}@media (min-width: 991px){.brz .css-njl3kp:hover,.brz [data-css-njl3kp]:hover{color:rgba(var(--brz-global-color8),0.8);border-color:rgba(var(--brz-global-color8),1);background-color:rgba(var(--brz-global-color5),1);background-image:none;}}@media (max-width: 991px){.brz .css-njl3kp,.brz [data-css-njl3kp]{width:46px;height:46px;font-size:24px;padding:10px;border-radius:23px;stroke-width:0;}}@media (max-width: 767px){.brz .css-njl3kp,.brz [data-css-njl3kp]{width:40px;height:40px;font-size:18px;padding:10px;border-radius:20px;stroke-width:0;}}</style><style class="brz-style">.brz .brz-css-lztbh > .brz-bg > .brz-bg-image{background-image:none;}.brz .brz-css-lztbh > .brz-bg > .brz-bg-image:after{content: "";background-image:none;}.brz .brz-css-lztbh > .brz-bg > .brz-bg-color{background-color:rgba(0, 0, 0, 0);background-image:none;}@media(max-width:991px) and (min-width:768px){.brz .brz-css-lztbh > .brz-bg > .brz-bg-image{background-image:none;}.brz .brz-css-lztbh > .brz-bg > .brz-bg-image:after{content: "";background-image:none;}.brz .brz-css-lztbh > .brz-bg > .brz-bg-color{background-color:rgba(0, 0, 0, 0);background-image:none;}}@media(max-width:767px){.brz .brz-css-lztbh > .brz-bg > .brz-bg-image{background-image:none;}.brz .brz-css-lztbh > .brz-bg > .brz-bg-image:after{content: "";background-image:none;}.brz .brz-css-lztbh > .brz-bg > .brz-bg-color{background-color:rgba(0, 0, 0, 0);background-image:none;}}
# .brz .brz-css-ymusa{justify-content:center;align-items:center;}.brz .brz-css-ymusa > .brz-container__wrap{width:1170px;}.brz .brz-css-ymusa > .brz-container__wrap .brz-popup2__close{display:block;top:-36px;right:-36px;left:auto;bottom:auto;color:rgba(255, 255, 255, 1);}.brz .brz-css-ymusa > .brz-container__wrap .brz-popup2__close .brz-icon-svg{font-size:16px;padding:0px;background-color:rgba(0, 0, 0, 0);border-radius:0px;}.brz .brz-css-ymusa .brz-container > .brz-row__container{min-height: auto;align-items:center;}@media(max-width:991px) and (min-width:768px){.brz .brz-css-ymusa{justify-content:center;align-items:center;}.brz .brz-css-ymusa > .brz-container__wrap{width:1170px;}.brz .brz-css-ymusa > .brz-container__wrap .brz-popup2__close{display:block;top:-36px;right:-36px;left:auto;bottom:auto;color:rgba(255, 255, 255, 1);}.brz .brz-css-ymusa > .brz-container__wrap .brz-popup2__close .brz-icon-svg{font-size:16px;padding:0px;background-color:rgba(0, 0, 0, 0);border-radius:0px;}.brz .brz-css-ymusa .brz-container > .brz-row__container{min-height: auto;align-items:center;}}@media(max-width:767px){.brz .brz-css-ymusa{justify-content:center;align-items:center;}.brz .brz-css-ymusa > .brz-container__wrap{width:1170px;}.brz .brz-css-ymusa > .brz-container__wrap .brz-popup2__close{display:block;top:-36px;right:-36px;left:auto;bottom:auto;color:rgba(255, 255, 255, 1);}.brz .brz-css-ymusa > .brz-container__wrap .brz-popup2__close .brz-icon-svg{font-size:16px;padding:0px;background-color:rgba(0, 0, 0, 0);border-radius:0px;}.brz .brz-css-ymusa .brz-container > .brz-row__container{min-height: auto;align-items:center;}}
# .brz .brz-css-yjzju{margin:0;z-index: auto;align-items:flex-start;}.brz .brz-css-yjzju > .brz-bg{border:0px solid rgba(102, 115, 141, 0);border-radius: 0px;max-width:100%;mix-blend-mode:normal;}.brz .brz-css-yjzju > .brz-bg > .brz-bg-image{background-image:none;display: block;}.brz .brz-css-yjzju > .brz-bg > .brz-bg-image:after{content: "";background-image:none;}.brz .brz-css-yjzju > .brz-bg > .brz-bg-color{background-color:rgba(0, 0, 0, 0);background-image:none;}.brz .brz-css-yjzju > .brz-bg > .brz-bg-map{display: none;}.brz .brz-css-yjzju > .brz-bg > .brz-bg-video{display: none;}.brz .brz-css-yjzju > .brz-row{border:0px solid transparent;}@media(min-width:991px){.brz .brz-css-yjzju{min-height: auto;display:flex;}.brz .brz-css-yjzju > .brz-bg{transition-duration:0.50s;transition-property: filter, box-shadow, background, border-radius, border-color;}.brz .brz-css-yjzju > .brz-bg > .brz-bg-image{transition-duration:0.50s;transition-property: filter, box-shadow, background, border-radius, border-color;}.brz .brz-css-yjzju > .brz-bg > .brz-bg-color{transition-duration:0.50s;transition-property: filter, box-shadow, background, border-radius, border-color;}.brz .brz-css-yjzju > .brz-bg > .brz-bg-video{transition-duration:0.50s;transition-property: filter, box-shadow, background, border-radius, border-color;}.brz .brz-css-yjzju > .brz-row{transition-duration:0.50s;transition-property: filter, box-shadow, background, border-radius, border-color;}}@media(max-width:991px) and (min-width:768px){.brz .brz-css-yjzju{margin:0;z-index: auto;align-items:flex-start;}.brz .brz-css-yjzju > .brz-bg{border:0px solid rgba(102, 115, 141, 0);border-radius: 0px;max-width:100%;mix-blend-mode:normal;}.brz .brz-css-yjzju > .brz-bg > .brz-bg-image{background-image:none;display: block;}.brz .brz-css-yjzju > .brz-bg > .brz-bg-image:after{content: "";background-image:none;}.brz .brz-css-yjzju > .brz-bg > .brz-bg-color{background-color:rgba(0, 0, 0, 0);background-image:none;}.brz .brz-css-yjzju > .brz-bg > .brz-bg-map{display: none;}.brz .brz-css-yjzju > .brz-bg > .brz-bg-video{display: none;}.brz .brz-css-yjzju > .brz-row{border:0px solid transparent;}}@media(max-width:991px) and (min-width:768px){.brz .brz-css-yjzju{min-height: auto;display:flex;}.brz .brz-css-yjzju > .brz-bg{transition-duration:0.50s;transition-property: filter, box-shadow, background, border-radius, border-color;}.brz .brz-css-yjzju > .brz-bg > .brz-bg-image{transition-duration:0.50s;transition-property: filter, box-shadow, background, border-radius, border-color;}.brz .brz-css-yjzju > .brz-bg > .brz-bg-color{transition-duration:0.50s;transition-property: filter, box-shadow, background, border-radius, border-color;}.brz .brz-css-yjzju > .brz-bg > .brz-bg-video{transition-duration:0.50s;transition-property: filter, box-shadow, background, border-radius, border-color;}.brz .brz-css-yjzju > .brz-row{flex-direction:row;flex-wrap:wrap;justify-content:flex-start;transition-duration:0.50s;transition-property: filter, box-shadow, background, border-radius, border-color;}}@media(max-width:767px){.brz .brz-css-yjzju{margin:0;z-index: auto;align-items:flex-start;}.brz .brz-css-yjzju > .brz-bg{border:0px solid rgba(102, 115, 141, 0);border-radius: 0px;max-width:100%;mix-blend-mode:normal;}.brz .brz-css-yjzju > .brz-bg > .brz-bg-image{background-image:none;display: block;}.brz .brz-css-yjzju > .brz-bg > .brz-bg-image:after{content: "";background-image:none;}.brz .brz-css-yjzju > .brz-bg > .brz-bg-color{background-color:rgba(0, 0, 0, 0);background-image:none;}.brz .brz-css-yjzju > .brz-bg > .brz-bg-map{display: none;}.brz .brz-css-yjzju > .brz-bg > .brz-bg-video{display: none;}.brz .brz-css-yjzju > .brz-row{border:0px solid transparent;}}@media(max-width:767px){.brz .brz-css-yjzju{min-height: auto;display:flex;}.brz .brz-css-yjzju > .brz-bg{transition-duration:0.50s;transition-property: filter, box-shadow, background, border-radius, border-color;}.brz .brz-css-yjzju > .brz-bg > .brz-bg-image{transitio ...
# .brz .brz-css-xjlem{padding:10px;max-width:100%;}@media(max-width:991px) and (min-width:768px){.brz .brz-css-xjlem{padding:0;max-width:100%;}}@media(max-width:767px){.brz .brz-css-xjlem{padding:0;max-width:100%;}}
# .brz .brz-css-rvwnq{z-index: auto;flex:1 1 50%;max-width:50%;justify-content:flex-start;}.brz .brz-css-rvwnq > .brz-bg{border:0px solid rgba(102, 115, 141, 0);border-radius: 0px;margin:0;mix-blend-mode:normal;}.brz .brz-css-rvwnq > .brz-bg > .brz-bg-image{background-image:none;display: block;}.brz .brz-css-rvwnq > .brz-bg > .brz-bg-image:after{content: "";background-image:none;}.brz .brz-css-rvwnq > .brz-bg > .brz-bg-color{background-color:rgba(0, 0, 0, 0);background-image:none;}.brz .brz-css-rvwnq > .brz-bg > .brz-bg-map{display: none;}.brz .brz-css-rvwnq > .brz-bg > .brz-bg-video{display: none;}@media(min-width:991px){.brz .brz-css-rvwnq > .brz-bg{transition-duration:0.50s;transition-property: filter, box-shadow, background, border-radius, border-color;}.brz .brz-css-rvwnq > .brz-bg > .brz-bg-image{transition-duration:0.50s;transition-property: filter, box-shadow, background, border-radius, border-color;}.brz .brz-css-rvwnq > .brz-bg > .brz-bg-color{transition-duration:0.50s;transition-property: filter, box-shadow, background, border-radius, border-color;}}@media(max-width:991px) and (min-width:768px){.brz .brz-css-rvwnq{z-index: auto;flex:1 1 50%;max-width:50%;justify-content:flex-start;}.brz .brz-css-rvwnq > .brz-bg{border:0px solid rgba(102, 115, 141, 0);border-radius: 0px;margin:0;mix-blend-mode:normal;}.brz .brz-css-rvwnq > .brz-bg > .brz-bg-image{background-image:none;display: block;}.brz .brz-css-rvwnq > .brz-bg > .brz-bg-image:after{content: "";background-image:none;}.brz .brz-css-rvwnq > .brz-bg > .brz-bg-color{background-color:rgba(0, 0, 0, 0);background-image:none;}.brz .brz-css-rvwnq > .brz-bg > .brz-bg-map{display: none;}.brz .brz-css-rvwnq > .brz-bg > .brz-bg-video{display: none;}}@media(max-width:991px) and (min-width:768px){.brz .brz-css-rvwnq > .brz-bg{transition-duration:0.50s;transition-property: filter, box-shadow, background, border-radius, border-color;}.brz .brz-css-rvwnq > .brz-bg > .brz-bg-image{transition-duration:0.50s;transition-property: filter, box-shadow, background, border-radius, border-color;}.brz .brz-css-rvwnq > .brz-bg > .brz-bg-color{transition-duration:0.50s;transition-property: filter, box-shadow, background, border-radius, border-color;}}@media(max-width:767px){.brz .brz-css-rvwnq{z-index: auto;flex:1 1 100%;max-width:100%;justify-content:flex-start;}.brz .brz-css-rvwnq > .brz-bg{border:0px solid rgba(102, 115, 141, 0);border-radius: 0px;margin:10px 0px 10px 0px;mix-blend-mode:normal;}.brz .brz-css-rvwnq > .brz-bg > .brz-bg-image{background-image:none;display: block;}.brz .brz-css-rvwnq > .brz-bg > .brz-bg-image:after{content: "";background-image:none;}.brz .brz-css-rvwnq > .brz-bg > .brz-bg-color{background-color:rgba(0, 0, 0, 0);background-image:none;}.brz .brz-css-rvwnq > .brz-bg > .brz-bg-map{display: none;}.brz .brz-css-rvwnq > .brz-bg > .brz-bg-video{display: none;}}@media(max-width:767px){.brz .brz-css-rvwnq > .brz-bg{transition-duration:0.50s;transition-property: filter, box-shadow, background, border-radius, border-color;}.brz .brz-css-rvwnq > .brz-bg > .brz-bg-image{transition-duration:0.50s;transition-property: filter, box-shadow, background, border-radius, border-color;}.brz .brz-css-rvwnq > .brz-bg > .brz-bg-color{transition-duration:0.50s;transition-property: filter, box-shadow, background, border-radius, border-color;}}
# .brz .brz-css-irhav{z-index: auto;margin:0;border:0px solid transparent;padding:5px 15px 5px 15px;min-height:auto;}@media(min-width:991px){.brz .brz-css-irhav{display:flex;transition-duration:0.50s;transition-property: filter, box-shadow, background, border-radius, border-color;}}@media(max-width:991px) and (min-width:768px){.brz .brz-css-irhav{z-index: auto;margin:0;border:0px solid transparent;padding:5px 15px 5px 15px;min-height:auto;}}@media(max-width:991px) and (min-width:768px){.brz .brz-css-irhav{display:flex;transition-duration:0.50s;transition-property: filter, box-shadow, background, border-radius, border-color;}}@media(max-width:767px){.brz .brz-css-irhav{z-index: auto;margin:10px 0px 10px 0px;border:0px solid transparent;padding:0;min-height:auto;}}@media(max-width:767px){.brz .brz-css-irhav{display:flex;transition-duration:0.50s;transition-property: filter, box-shadow, background, border-radius, border-color;}}
# .brz .brz-css-ckmip{z-index: auto;position:relative;margin:10px 0px 10px 0px;}@media(min-width:991px){.brz .brz-css-ckmip{display:flex;position:relative;}}@media(max-width:991px) and (min-width:768px){.brz .brz-css-ckmip{z-index: auto;position:relative;margin:10px 0px 10px 0px;}}@media(max-width:991px) and (min-width:768px){.brz .brz-css-ckmip{display:flex;position:relative;}}@media(max-width:767px){.brz .brz-css-ckmip{z-index: auto;position:relative;margin:10px 0px 10px 0px;}}@media(max-width:767px){.brz .brz-css-ckmip{display:flex;position:relative;}}
# .brz .brz-css-dfksa{justify-content:center;padding:0;margin:0px -5px -20px -5px;}@media(max-width:991px) and (min-width:768px){.brz .brz-css-dfksa{justify-content:center;padding:0;margin:0px -5px -20px -5px;}}@media(max-width:767px){.brz .brz-css-dfksa{justify-content:center;padding:0;margin:0px -5px -20px -5px;}}
# .brz .brz-css-libaq{padding:0px 5px 20px 5px;}@media(max-width:991px) and (min-width:768px){.brz .brz-css-libaq{padding:0px 5px 20px 5px;}}@media(max-width:767px){.brz .brz-css-libaq{padding:0px 5px 20px 5px;}}
# .brz .brz-css-dsrad > .brz-bg > .brz-bg-color{background-color:rgba(25, 27, 33, 0);}@media(max-width:991px) and (min-width:768px){.brz .brz-css-dsrad > .brz-bg > .brz-bg-color{background-color:rgba(25, 27, 33, 0);}}@media(max-width:767px){.brz .brz-css-dsrad > .brz-bg > .brz-bg-color{background-color:rgba(25, 27, 33, 0);}}
# .brz .brz-css-lilgz{justify-content:flex-end;align-items:flex-end;}.brz .brz-css-lilgz > .brz-container__wrap{width:10px;}.brz .brz-css-lilgz > .brz-container__wrap .brz-popup2__close{display:none;}@media(max-width:991px) and (min-width:768px){.brz .brz-css-lilgz{justify-content:flex-end;align-items:flex-end;}.brz .brz-css-lilgz > .brz-container__wrap{width:10px;}.brz .brz-css-lilgz > .brz-container__wrap .brz-popup2__close{display:none;}}@media(max-width:767px){.brz .brz-css-lilgz{justify-content:flex-end;align-items:flex-end;}.brz .brz-css-lilgz > .brz-container__wrap{width:10px;}.brz .brz-css-lilgz > .brz-container__wrap .brz-popup2__close{display:none;}}
# .brz .brz-css-erbfz{margin:0px 20px 50px 0px;}.brz .brz-css-erbfz > .brz-bg > .brz-bg-color{background-color:rgba(255, 255, 255, 0);}@media(max-width:991px) and (min-width:768px){.brz .brz-css-erbfz{margin:0;}.brz .brz-css-erbfz > .brz-bg > .brz-bg-color{background-color:rgba(255, 255, 255, 0);}}@media(max-width:767px){.brz .brz-css-erbfz{margin:0;}.brz .brz-css-erbfz > .brz-bg > .brz-bg-color{background-color:rgba(255, 255, 255, 0);}}
# .brz .brz-css-lhayl{padding:0;}@media(max-width:991px) and (min-width:768px){.brz .brz-css-lhayl{padding:0;}}@media(max-width:767px){.brz .brz-css-lhayl{padding:0;}}
# .brz .brz-css-qtwmf{flex:1 1 100%;max-width:100%;}@media(max-width:991px) and (min-width:768px){.brz .brz-css-qtwmf{flex:1 1 100%;max-width:100%;}}@media(max-width:767px){.brz .brz-css-qtwmf{flex:1 1 100%;max-width:100%;}}
# .brz .brz-css-csnle{padding:0;}@media(max-width:991px) and (min-width:768px){.brz .brz-css-csnle{padding:5px 15px 5px 15px;}}@media(max-width:767px){.brz .brz-css-csnle{padding:0;}}
# .brz .brz-css-ulzyp{z-index: 11;margin:0;}@media(min-width:991px){.brz .brz-css-ulzyp{position:absolute;width:60px;top: unset;bottom: 0px;right: 0px;left: unset;}}@media(max-width:991px) and (min-width:768px){.brz .brz-css-ulzyp{z-index: 11;margin:10px 5px 30px 0px;}}@media(max-width:991px) and (min-width:768px){.brz .brz-css-ulzyp{position:absolute;width:60px;top: unset;bottom: 0px;right: 0px;left: unset;}}@media(max-width:767px){.brz .brz-css-ulzyp{z-index: 11;margin:10px 5px 30px 0px;}}@media(max-width:767px){.brz .brz-css-ulzyp{position:absolute;width:60px;top: unset;bottom: 0px;right: 0px;left: unset;}}
# .brz .brz-css-jnonu{justify-content:flex-end;padding:0px 10px 30px 0px;}@media(max-width:991px) and (min-width:768px){.brz .brz-css-jnonu{justify-content:flex-end;padding:0;}}@media(max-width:767px){.brz .brz-css-jnonu{justify-content:flex-end;padding:0;}}
# </style>
# <style class="brz-style"></style><style class="brz-style">@media(min-width:991px){.brz .brz-css-kfhrs{display:block;}}@media(max-width:991px) and (min-width:768px){.brz .brz-css-kfhrs{display:block;}}@media(max-width:767px){.brz .brz-css-kfhrs{display:block;}}
# .brz .brz-css-aocvm{padding:75px 0px 75px 0px;margin:0;}.brz .brz-css-aocvm > .brz-bg{border:0px solid rgba(102, 115, 141, 0);border-radius: 0px;}.brz .brz-css-aocvm > .brz-bg > .brz-bg-image{background-image:none;}.brz .brz-css-aocvm > .brz-bg > .brz-bg-image:after{content: "";background-image:none;}.brz .brz-css-aocvm > .brz-bg > .brz-bg-color{background-color:rgba(0, 0, 0, 0);background-image:none;}.brz .brz-css-aocvm > .brz-bg > .brz-bg-shape__top{background-size: 100% 100px; height: 100px;transform: rotateX(0deg) rotateY(0deg);z-index: auto;}.brz .brz-css-aocvm > .brz-bg > .brz-bg-shape__top::after{background-image: none; -webkit-mask-image: none;background-size: 100% 100px; height: 100px;}.brz .brz-css-aocvm > .brz-bg > .brz-bg-shape__bottom{background-size: 100% 100px; height: 100px;transform: rotateX(-180deg) rotateY(-180deg);z-index: auto;}.brz .brz-css-aocvm > .brz-bg > .brz-bg-shape__bottom::after{background-image: none; -webkit-mask-image: none;background-size: 100% 100px; height: 100px;}@media(max-width:991px) and (min-width:768px){.brz .brz-css-aocvm{padding:50px 15px 50px 15px;margin:0;}.brz .brz-css-aocvm > .brz-bg{border:0px solid rgba(102, 115, 141, 0);border-radius: 0px;}.brz .brz-css-aocvm > .brz-bg > .brz-bg-image{background-image:none;}.brz .brz-css-aocvm > .brz-bg > .brz-bg-image:after{content: "";background-image:none;}.brz .brz-css-aocvm > .brz-bg > .brz-bg-color{background-color:rgba(0, 0, 0, 0);background-image:none;}.brz .brz-css-aocvm > .brz-bg > .brz-bg-shape__top{background-size: 100% 100px; height: 100px;transform: rotateX(0deg) rotateY(0deg);z-index: auto;}.brz .brz-css-aocvm > .brz-bg > .brz-bg-shape__top::after{background-image: none; -webkit-mask-image: none;background-size: 100% 100px; height: 100px;}.brz .brz-css-aocvm > .brz-bg > .brz-bg-shape__bottom{background-size: 100% 100px; height: 100px;transform: rotateX(-180deg) rotateY(-180deg);z-index: auto;}.brz .brz-css-aocvm > .brz-bg > .brz-bg-shape__bottom::after{background-image: none; -webkit-mask-image: none;background-size: 100% 100px; height: 100px;}}@media(max-width:767px){.brz .brz-css-aocvm{padding:25px 15px 25px 15px;margin:0;}.brz .brz-css-aocvm > .brz-bg{border:0px solid rgba(102, 115, 141, 0);border-radius: 0px;}.brz .brz-css-aocvm > .brz-bg > .brz-bg-image{background-image:none;}.brz .brz-css-aocvm > .brz-bg > .brz-bg-image:after{content: "";background-image:none;}.brz .brz-css-aocvm > .brz-bg > .brz-bg-color{background-color:rgba(0, 0, 0, 0);background-image:none;}.brz .brz-css-aocvm > .brz-bg > .brz-bg-shape__top{background-size: 100% 100px; height: 100px;transform: rotateX(0deg) rotateY(0deg);z-index: auto;}.brz .brz-css-aocvm > .brz-bg > .brz-bg-shape__top::after{background-image: none; -webkit-mask-image: none;background-size: 100% 100px; height: 100px;}.brz .brz-css-aocvm > .brz-bg > .brz-bg-shape__bottom{background-size: 100% 100px; height: 100px;transform: rotateX(-180deg) rotateY(-180deg);z-index: auto;}.brz .brz-css-aocvm > .brz-bg > .brz-bg-shape__bottom::after{background-image: none; -webkit-mask-image: none;background-size: 100% 100px; height: 100px;}}
# .brz .brz-css-wigbd{border:0px solid transparent;}@media(min-width:991px){.brz .brz-css-wigbd{max-width: calc(1 * var(--brz-section-container-max-width, 1170px));}}@media(max-width:991px) and (min-width:768px){.brz .brz-css-wigbd{border:0px solid transparent;}}@media(max-width:991px) and (min-width:768px){.brz .brz-css-wigbd{max-width: 100%}}@media(max-width:767px){.brz .brz-css-wigbd{border:0px solid transparent;}}@media(max-width:767px){.brz .brz-css-wigbd{max-width: 100%}}
# .brz .brz-css-qzhbi{margin:0;z-index: auto;align-items:flex-start;}.brz .brz-css-qzhbi > .brz-bg{border:0px solid rgba(102, 115, 141, 0);border-radius: 0px;max-width:100%;mix-blend-mode:normal;}.brz .brz-css-qzhbi > .brz-bg > .brz-bg-image{background-image:none;display: block;}.brz .brz-css-qzhbi > .brz-bg > .brz-bg-image:after{content: "";background-image:none;}.brz .brz-css-qzhbi > .brz-bg > .brz-bg-color{background-color:rgba(0, 0, 0, 0);background-image:none;}.brz .brz-css-qzhbi > .brz-bg > .brz-bg-map{display: none;}.brz .brz-css-qzhbi > .brz-bg > .brz-bg-video{display: none;}.brz .brz-css-qzhbi > .brz-row{border:0px solid transparent;}@media(min-width:991px){.brz .brz-css-qzhbi{min-height: auto;display:flex;}.brz .brz-css-qzhbi > .brz-bg{transition-duration:0.50s;transition-property: filter, box-shadow, background, border-radius, border-color;}.brz .brz-css-qzhbi > .brz-bg > .brz-bg-image{transition-duration:0.50s;transition-property: filter, box-shadow, background, border-radius, border-color;}.brz .brz-css-qzhbi > .brz-bg > .brz-bg-color{transition-duration:0.50s;transition-property: filter, box-shadow, background, border-radius, border-color;}.brz .brz-css-qzhbi > .brz-bg > .brz-bg-video{transition-duration:0.50s;transition-property: filter, box-shadow, background, border-radius, border-color;}.brz .brz-css-qzhbi > .brz-row{transition-duration:0.50s;transition-property: filter, box-shadow, background, border-radius, border-color;}}@media(max-width:991px) and (min-width:768px){.brz .brz-css-qzhbi{margin:0;z-index: auto;align-items:flex-start;}.brz .brz-css-qzhbi > .brz-bg{border:0px solid rgba(102, 115, 141, 0);border-radius: 0px;max-width:100%;mix-blend-mode:normal;}.brz .brz-css-qzhbi > .brz-bg > .brz-bg-image{background-image:none;display: block;}.brz .brz-css-qzhbi > .brz-bg > .brz-bg-image:after{content: "";background-image:none;}.brz .brz-css-qzhbi > .brz-bg > .brz-bg-color{background-color:rgba(0, 0, 0, 0);background-image:none;}.brz .brz-css-qzhbi > .brz-bg > .brz-bg-map{display: none;}.brz .brz-css-qzhbi > .brz-bg > .brz-bg-video{display: none;}.brz .brz-css-qzhbi > .brz-row{border:0px solid transparent;}}@media(max-width:991px) and (min-width:768px){.brz .brz-css-qzhbi{min-height: auto;display:flex;}.brz .brz-css-qzhbi > .brz-bg{transition-duration:0.50s;transition-property: filter, box-shadow, background, border-radius, border-color;}.brz .brz-css-qzhbi > .brz-bg > .brz-bg-image{transition-duration:0.50s;transition-property: filter, box-shadow, background, border-radius, border-color;}.brz .brz-css-qzhbi > .brz-bg > .brz-bg-color{transition-duration:0.50s;transition-property: filter, box-shadow, background, border-radius, border-color;}.brz .brz-css-qzhbi > .brz-bg > .brz-bg-video{transition-duration:0.50s;transition-property: filter, box-shadow, background, border-radius, border-color;}.brz .brz-css-qzhbi > .brz-row{flex-direction:row;flex-wrap:wrap;justify-content:flex-start;transition-duration:0.50s;transition-property: filter, box-shadow, background, border-radius, border-color;}}@media(max-width:767px){.brz .brz-css-qzhbi{margin:0;z-index: auto;align-items:flex-start;}.brz .brz-css-qzhbi > .brz-bg{border:0px solid rgba(102, 115, 141, 0);border-radius: 0px;max-width:100%;mix-blend-mode:normal;}.brz .brz-css-qzhbi > .brz-bg > .brz-bg-image{background-image:none;display: block;}.brz .brz-css-qzhbi > .brz-bg > .brz-bg-image:after{content: "";background-image:none;}.brz .brz-css-qzhbi > .brz-bg > .brz-bg-color{background-color:rgba(0, 0, 0, 0);background-image:none;}.brz .brz-css-qzhbi > .brz-bg > .brz-bg-map{display: none;}.brz .brz-css-qzhbi > .brz-bg > .brz-bg-video{display: none;}.brz .brz-css-qzhbi > .brz-row{border:0px solid transparent;}}@media(max-width:767px){.brz .brz-css-qzhbi{min-height: auto;display:flex;}.brz .brz-css-qzhbi > .brz-bg{transition-duration:0.50s;transition-property: filter, box-shadow, background, border-radius, border-color;}.brz .brz-css-qzhbi > .brz-bg > .brz-bg-image{transitio ...
# .brz .brz-css-qhdmb{padding:10px;max-width:100%;}@media(max-width:991px) and (min-width:768px){.brz .brz-css-qhdmb{padding:0;max-width:100%;}}@media(max-width:767px){.brz .brz-css-qhdmb{padding:0;max-width:100%;}}
# .brz .brz-css-onacz{z-index: auto;flex:1 1 50%;max-width:50%;justify-content:flex-start;}.brz .brz-css-onacz > .brz-bg{border:0px solid rgba(102, 115, 141, 0);border-radius: 0px;margin:0;mix-blend-mode:normal;}.brz .brz-css-onacz > .brz-bg > .brz-bg-image{background-image:none;display: block;}.brz .brz-css-onacz > .brz-bg > .brz-bg-image:after{content: "";background-image:none;}.brz .brz-css-onacz > .brz-bg > .brz-bg-color{background-color:rgba(0, 0, 0, 0);background-image:none;}.brz .brz-css-onacz > .brz-bg > .brz-bg-map{display: none;}.brz .brz-css-onacz > .brz-bg > .brz-bg-video{display: none;}@media(min-width:991px){.brz .brz-css-onacz > .brz-bg{transition-duration:0.50s;transition-property: filter, box-shadow, background, border-radius, border-color;}.brz .brz-css-onacz > .brz-bg > .brz-bg-image{transition-duration:0.50s;transition-property: filter, box-shadow, background, border-radius, border-color;}.brz .brz-css-onacz > .brz-bg > .brz-bg-color{transition-duration:0.50s;transition-property: filter, box-shadow, background, border-radius, border-color;}}@media(max-width:991px) and (min-width:768px){.brz .brz-css-onacz{z-index: auto;flex:1 1 50%;max-width:50%;justify-content:flex-start;}.brz .brz-css-onacz > .brz-bg{border:0px solid rgba(102, 115, 141, 0);border-radius: 0px;margin:0;mix-blend-mode:normal;}.brz .brz-css-onacz > .brz-bg > .brz-bg-image{background-image:none;display: block;}.brz .brz-css-onacz > .brz-bg > .brz-bg-image:after{content: "";background-image:none;}.brz .brz-css-onacz > .brz-bg > .brz-bg-color{background-color:rgba(0, 0, 0, 0);background-image:none;}.brz .brz-css-onacz > .brz-bg > .brz-bg-map{display: none;}.brz .brz-css-onacz > .brz-bg > .brz-bg-video{display: none;}}@media(max-width:991px) and (min-width:768px){.brz .brz-css-onacz > .brz-bg{transition-duration:0.50s;transition-property: filter, box-shadow, background, border-radius, border-color;}.brz .brz-css-onacz > .brz-bg > .brz-bg-image{transition-duration:0.50s;transition-property: filter, box-shadow, background, border-radius, border-color;}.brz .brz-css-onacz > .brz-bg > .brz-bg-color{transition-duration:0.50s;transition-property: filter, box-shadow, background, border-radius, border-color;}}@media(max-width:767px){.brz .brz-css-onacz{z-index: auto;flex:1 1 100%;max-width:100%;justify-content:flex-start;}.brz .brz-css-onacz > .brz-bg{border:0px solid rgba(102, 115, 141, 0);border-radius: 0px;margin:10px 0px 10px 0px;mix-blend-mode:normal;}.brz .brz-css-onacz > .brz-bg > .brz-bg-image{background-image:none;display: block;}.brz .brz-css-onacz > .brz-bg > .brz-bg-image:after{content: "";background-image:none;}.brz .brz-css-onacz > .brz-bg > .brz-bg-color{background-color:rgba(0, 0, 0, 0);background-image:none;}.brz .brz-css-onacz > .brz-bg > .brz-bg-map{display: none;}.brz .brz-css-onacz > .brz-bg > .brz-bg-video{display: none;}}@media(max-width:767px){.brz .brz-css-onacz > .brz-bg{transition-duration:0.50s;transition-property: filter, box-shadow, background, border-radius, border-color;}.brz .brz-css-onacz > .brz-bg > .brz-bg-image{transition-duration:0.50s;transition-property: filter, box-shadow, background, border-radius, border-color;}.brz .brz-css-onacz > .brz-bg > .brz-bg-color{transition-duration:0.50s;transition-property: filter, box-shadow, background, border-radius, border-color;}}
# .brz .brz-css-hkmku{z-index: auto;margin:0;border:0px solid transparent;padding:5px 15px 5px 15px;min-height:auto;}@media(min-width:991px){.brz .brz-css-hkmku{display:flex;transition-duration:0.50s;transition-property: filter, box-shadow, background, border-radius, border-color;}}@media(max-width:991px) and (min-width:768px){.brz .brz-css-hkmku{z-index: auto;margin:0;border:0px solid transparent;padding:5px 15px 5px 15px;min-height:auto;}}@media(max-width:991px) and (min-width:768px){.brz .brz-css-hkmku{display:flex;transition-duration:0.50s;transition-property: filter, box-shadow, background, border-radius, border-color;}}@media(max-width:767px){.brz .brz-css-hkmku{z-index: auto;margin:10px 0px 10px 0px;border:0px solid transparent;padding:0;min-height:auto;}}@media(max-width:767px){.brz .brz-css-hkmku{display:flex;transition-duration:0.50s;transition-property: filter, box-shadow, background, border-radius, border-color;}}
# .brz .brz-css-eridv{padding:0;margin:10px 0px 10px 0px;justify-content:center;position:relative;}@media(min-width:991px){.brz .brz-css-eridv{display:flex;z-index: auto;position:relative;}}@media(max-width:991px) and (min-width:768px){.brz .brz-css-eridv{padding:0;margin:10px 0px 10px 0px;justify-content:center;position:relative;}}@media(max-width:991px) and (min-width:768px){.brz .brz-css-eridv{display:flex;z-index: auto;position:relative;}}@media(max-width:767px){.brz .brz-css-eridv{padding:0;margin:10px 0px 10px 0px;justify-content:center;position:relative;}}@media(max-width:767px){.brz .brz-css-eridv{display:flex;z-index: auto;position:relative;}}
# ...
# <table aria-label="police_telephone_index.csv" class="foo-table ninja_footable foo_table_3659 ninja_table_unique_id_1457992019_3659 ui table nt_type_ajax_table selectable striped vertical_centered footable-paging-right ninja_table_pro" data-filter-delay="1000" data-footable_id="3659" data-ninja_table_instance="ninja_table_instance_0" data-unique_identifier="ninja_table_unique_id_1457992019_3659" id="footable_3659">
# <colgroup>
# <col class="ninja_column_0"/>
# <col class="ninja_column_1"/>
# <col class="ninja_column_2"/>
# <col class="ninja_column_3"/>
# <col class="ninja_column_4"/>
# </colgroup>
# </table>
# </div>
# </div></div></div></div></div></section><footer class="brz-footer brz-css-pmxbm brz-css-tstxf" data-custom-id="gqsxwoontorlxvtdqkqmbxgbpmytnaszfxgb" data-uid="gqsxwoontorlxvtdqkqmbxgbpmytnaszfxgb" id="gqsxwoontorlxvtdqkqmbxgbpmytnaszfxgb"><div class="brz-bg"><div class="brz-bg-color"></div></div><div class="brz-container brz-css-hrcrb brz-css-pubvn"><div class="brz-row__container brz-css-qzhbi" data-custom-id="djarhsddklalewlwbvcgwmaqcyglajkttahf"><div class="brz-row brz-css-qhdmb brz-css-cyurx"><div class="brz-columns brz-css-onacz brz-css-hpcdq" data-custom-id="hlqsbpdzcmrnpbqnlrpzuogytsxoyikfhzuu"><div class="brz-bg"></div><div class="brz-column__items brz-css-hkmku brz-css-tsflu"><div class="brz-css-eridv brz-css-yivns brz-wrapper"><div class="brz-rich-text brz-rich-text__custom brz-css-zgyid" data-custom-id="mnrvghiobmmcjhuuhydrzkksrzxhyvkqewel"><div><p class="brz-css-ckocw" data-generated-css="brz-css-qkdsl" data-uniq-id="wfioz"><span class="brz-cp-color2">Design by Sri Lanka Police Information Technology Division.</span></p></div></div></div></div></div></div></div></div></footer></div>
# <!-- POPUP BODY -->
# <div class="brz-popup2 brz-popup2__preview brz-conditions-popup brz-conditions-internal-popup brz-css-lztbh brz-css-dsrad" data-brz-popup="qadbeqgfwnngdwssxfnejfxosmymkeeumtuv" data-custom-id="qadbeqgfwnngdwssxfnejfxosmymkeeumtuv" data-page_load="0" data-scroll_page="true" data-trigger_once="false" id="qadbeqgfwnngdwssxfnejfxosmymkeeumtuv"><div class="brz-bg"><div class="brz-bg-color"></div></div><div class="brz-popup2__inner brz-d-xs-flex brz-flex-xs-wrap brz-css-ymusa brz-css-lilgz"><div class="brz-container__wrap"><div class="brz-popup2__close"><svg class="brz-icon-svg" data-name="close-popup" data-type="editor" version="1.1" viewbox="0 0 16 16" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"> <g fill="none" fill-rule="evenodd" id="close-popup" stroke="none" stroke-linecap="square" stroke-width="1"> <path d="M1.5,1.5 L14.5384048,14.5384048" fill-rule="nonzero" id="Line-2" stroke="currentColor"></path> <path d="M1.5,1.5 L14.5384048,14.5384048" fill-rule="nonzero" id="Line-2" stroke="currentColor" transform="translate(8.000000, 8.000000) scale(-1, 1) translate(-8.000000, -8.000000) "></path> </g> </svg></div><div class="brz-container"><div class="brz-row__container brz-css-yjzju brz-css-erbfz" data-custom-id="imevbjzjyuzeoxteuugkwtftcacxljmombwg"><div class="brz-bg"><div class="brz-bg-color"></div></div><div class="brz-row brz-css-xjlem brz-css-lhayl"><div class="brz-columns brz-css-rvwnq brz-css-qtwmf" data-custom-id="odijxhmewjeqxnnkewljxjlkkrvklabcufvu"><div class="brz-column__items brz-css-irhav brz-css-csnle"><div class="brz-wrapper-clone brz-css-ckmip brz-css-ulzyp"><div class="brz-d-xs-flex brz-flex-xs-wrap brz-css-dfksa brz-css-jnonu"><div class="brz-wrapper-clone__item brz-css-libaq" id="nxvlybynsmpodcehhxlmiuqhhcnpokrpyuem"><div class="brz-icon__container" data-custom-id="nxvlybynsmpodcehhxlmiuqhhcnpokrpyuem" id=""><a class="brz-a" data-brz-link-type="external" href="https://www.facebook.com/Police-Media-Division-PMD-2095754130735409" id="" rel="noopener" target="_blank"><span class="brz-span brz-icon css-njl3kp"><svg class="brz-icon-svg" data-name="logo-fb-simple" data-type="glyph" version="1.1" viewbox="0 0 24 24" x="0px" xml:space="preserve" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" y="0px"><g class="nc-icon-wrapper" fill="currentColor"><path d="M9.03153,23L9,13H5V9h4V6.5C9,2.7886,11.29832,1,14.60914,1c1.58592,0,2.94893,0.11807,3.34615,0.17085 v3.87863l-2.29623,0.00104c-1.80061,0-2.14925,0.85562-2.14925,2.11119V9H18.75l-2,4h-3.24019v10H9.03153z" fill="currentColor"></path></g></svg></span></a></div></div><div class="brz-wrapper-clone__item brz-css-libaq" id="mgiwnqcitvexqvzwggkbmhplmkzkolkuzjbq"><div class="brz-icon__container" data-custom-id="mgiwnqcitvexqvzwggkbmhplmkzkolkuzjbq" id=""><a class="brz-a" data-brz-link-type="external" href="https://twitter.com/SL_PoliceMedia" id="" rel="noopener" target="_blank"><span class="brz-span brz-icon css-njl3kp"><svg class="brz-icon-svg" data-name="logo-twitter" data-type="glyph" version="1.1" viewbox="0 0 24 24" x="0px" xml:space="preserve" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" y="0px"><g class="nc-icon-wrapper" fill="currentColor"><path d="M24,4.6c-0.9,0.4-1.8,0.7-2.8,0.8c1-0.6,1.8-1.6,2.2-2.7c-1,0.6-2,1-3.1,1.2c-0.9-1-2.2-1.6-3.6-1.6 c-2.7,0-4.9,2.2-4.9,4.9c0,0.4,0,0.8,0.1,1.1C7.7,8.1,4.1,6.1,1.7,3.1C1.2,3.9,1,4.7,1,5.6c0,1.7,0.9,3.2,2.2,4.1 C2.4,9.7,1.6,9.5,1,9.1c0,0,0,0,0,0.1c0,2.4,1.7,4.4,3.9,4.8c-0.4,0.1-0.8,0.2-1.3,0.2c-0.3,0-0.6,0-0.9-0.1c0.6,2,2.4,3.4,4.6,3.4 c-1.7,1.3-3.8,2.1-6.1,2.1c-0.4,0-0.8,0-1.2-0.1c2.2,1.4,4.8,2.2,7.5,2.2c9.1,0,14-7.5,14-14c0-0.2,0-0.4,0-0.6 C22.5,6.4,23.3,5.5,24,4.6z" fill="currentColor"></path></g></svg></span></a></div></div><div class="brz-wrapper-clone__item brz-css-libaq" id="odrkjrrypvjrtsoakixcyzpuwpbmntlhzavq"><div class="brz-icon__container" data-custom-id="odrkjrrypvjrtsoakixcyzpuwpbmntlhzavq" id=""><a class="brz-a" data-brz ...
# <!-- POPUP BODY END-->
# <script type="text/javascript">
#                 window['ninja_table_instance_0'] = {"table_id":"3659","title":"police_telephone_index.csv","caption":"","columns":[{"name":"designationstation","key":"designationstation","title":"\ufeffDesignation \/ Station","breakpoints":"","type":"text","visible":true,"classes":["ninja_column_0","ninja_clmn_nm_designationstation"],"filterable":true,"sortable":true,"original":{"key":"designationstation","name":"\ufeffDesignation \/ Station","breakpoints":""}},{"name":"rank","key":"rank","title":"Rank","breakpoints":"","type":"text","visible":true,"classes":["ninja_column_1","ninja_clmn_nm_rank"],"filterable":true,"sortable":true,"original":{"key":"rank","name":"Rank","breakpoints":""}},{"name":"name","key":"name","title":"Name","breakpoints":"","type":"text","visible":true,"classes":["ninja_column_2","ninja_clmn_nm_name"],"filterable":true,"sortable":true,"original":{"key":"name","name":"Name","breakpoints":""}},{"name":"general","key":"general","title":"General","breakpoints":"","type":"text","visible":true,"classes":["ninja_column_3","ninja_clmn_nm_general"],"filterable":true,"sortable":true,"original":{"key":"general","name":"General","breakpoints":""}},{"name":"mobile","key":"mobile","title":"Mobile","breakpoints":"","type":"text","visible":true,"classes":["ninja_column_4","ninja_clmn_nm_mobile"],"filterable":true,"sortable":true,"original":{"key":"mobile","name":"Mobile","breakpoints":""}}],"original_columns":[{"key":"designationstation","name":"\ufeffDesignation \/ Station","breakpoints":""},{"key":"rank","name":"Rank","breakpoints":""},{"key":"name","name":"Name","breakpoints":""},{"key":"general","name":"General","breakpoints":""},{"key":"mobile","name":"Mobile","breakpoints":""}],"settings":{"filtering":true,"togglePosition":"first","paging":20,"pager":false,"page_sizes":["10","20","50","100"],"sorting":true,"default_sorting":"old_first","defualt_filter":false,"defualt_filter_column":null,"expandFirst":false,"expandAll":false,"i18n":{"search_in":"Search in","search":"Search","no_result_text":"No Result Found"},"shouldNotCache":false,"skip_rows":0,"limit_rows":0,"use_parent_width":false,"info":"","enable_html_cache":null,"html_caching_minutes":null,"extra_css_class":"","disable_sticky_on_mobile":null,"has_formula":"no","filter_selects":[]},"render_type":"ajax_table","custom_css":{"ninja_column_0":[],"ninja_column_1":[],"ninja_column_2":[],"ninja_column_3":[],"ninja_column_4":[]},"instance_name":"ninja_table_instance_0","table_version":"4.2.3","provider":"default","uniqueID":"ninja_table_unique_id_1457992019_3659","editing":{"enabled":false,"editing":false,"check_editing":"no","deleting":false,"alwaysShow":false,"own_data_only":null,"addText":"New Row","hideText":"Cancel","showText":"Edit Rows","position":"right","addModalLabel":"Add Data","editModalLabel":"Edit Data","defaultValues":[]},"init_config":{"toggleColumn":"first","cascade":true,"useParentWidth":false,"columns":[{"name":"designationstation","key":"designationstation","title":"\ufeffDesignation \/ Station","breakpoints":"","type":"text","visible":true,"classes":["ninja_column_0","ninja_clmn_nm_designationstation"],"filterable":true,"sortable":true,"original":{"key":"designationstation","name":"\ufeffDesignation \/ Station","breakpoints":""}},{"name":"rank","key":"rank","title":"Rank","breakpoints":"","type":"text","visible":true,"classes":["ninja_column_1","ninja_clmn_nm_rank"],"filterable":true,"sortable":true,"original":{"key":"rank","name":"Rank","breakpoints":""}},{"name":"name","key":"name","title":"Name","breakpoints":"","type":"text","visible":true,"classes":["ninja_column_2","ninja_clmn_nm_name"],"filterable":true,"sortable":true,"original":{"key":"name","name":"Name","breakpoints":""}},{"name":"general","key":"general","title":"General","breakpoints":"","type":"text","visible":true,"classes":["ninja_column_3","ninja_clmn_nm_general"],"filterable":true,"sortable":true,"original":{"key":"general","name":"General","breakpoints":""}},{"name":"mobile","k ...
# <script async="" id="blocksy-ext-cookies-consent-scripts-js" src="https://www.police.lk/wp-content/plugins/blocksy-companion-pro/framework/extensions/cookies-consent/static/bundle/main.js?ver=1.8.46"></script>
# <script id="ct-scripts-js-extra">
# var ct_localizations = {"ajax_url":"https:\/\/www.police.lk\/wp-admin\/admin-ajax.php","nonce":"dba3b4b8f7","public_url":"https:\/\/www.police.lk\/wp-content\/themes\/blocksy\/static\/bundle\/","rest_url":"https:\/\/www.police.lk\/index.php?rest_route=\/","search_url":"https:\/\/www.police.lk\/?s=QUERY_STRING","show_more_text":"Show more","more_text":"More","search_live_results":"Search results","search_live_no_result":"No results","search_live_one_result":"You got %s result. Please press Tab to select it.","search_live_many_results":"You got %s results. Please press Tab to select one.","expand_submenu":"Expand dropdown menu","collapse_submenu":"Collapse dropdown menu","dynamic_js_chunks":[{"id":"blocksy_pro_micro_popups","selector":".ct-popup","url":"https:\/\/www.police.lk\/wp-content\/plugins\/blocksy-companion-pro\/framework\/premium\/static\/bundle\/micro-popups.js"},{"id":"blocksy_dark_mode","selector":"[data-id=\"dark-mode-switcher\"]","url":"https:\/\/www.police.lk\/wp-content\/plugins\/blocksy-companion-pro\/static\/bundle\/dark-mode.js","trigger":"click"},{"id":"blocksy_sticky_header","selector":"header [data-sticky]","url":"https:\/\/www.police.lk\/wp-content\/plugins\/blocksy-companion-pro\/static\/bundle\/sticky.js"}],"dynamic_styles":{"lazy_load":"https:\/\/www.police.lk\/wp-content\/themes\/blocksy\/static\/bundle\/non-critical-styles.min.css","search_lazy":"https:\/\/www.police.lk\/wp-content\/themes\/blocksy\/static\/bundle\/non-critical-search-styles.min.css"},"dynamic_styles_selectors":[{"selector":"#account-modal","url":"https:\/\/www.police.lk\/wp-content\/plugins\/blocksy-companion-pro\/static\/bundle\/account-lazy.min.css"}]};
# </script>
# <script id="ct-scripts-js" src="https://www.police.lk/wp-content/themes/blocksy/static/bundle/main.js?ver=1.8.46"></script>
# <script id="__ytprefsfitvids__-js" src="https://www.police.lk/wp-content/plugins/youtube-embed-plus/scripts/fitvids.min.js?ver=14.1.2"></script>
# <script class="brz-script brz-script-preview-lib" data-group="group-jq" id="brizy-asset-group-jq-20-js" src="https://www.police.lk/wp-content/plugins/brizy/public/editor-build/241-wp/editor/js/group-jq.js?ver=2.4.5"></script>
# <script class="brz-script brz-script-preview-lib-pro" data-group="group-2" id="brizy-asset-group-2-21-js" src="https://www.police.lk/wp-content/plugins/brizy-pro/public/editor-build/116-wp/js/group-2.pro.js?ver=2.4.6"></script>
# <script class="brz-script brz-script-preview-pro" id="brizy-asset-main-30-js" src="https://www.police.lk/wp-content/plugins/brizy-pro/public/editor-build/116-wp/js/preview.pro.js?ver=2.4.6"></script>
# <script class="brz-script brz-script-emit" id="brizy-asset-main-30-js-after">
# document.addEventListener('DOMContentLoaded', () => window.Brz.emit("init.dom", jQuery(document.body)));
# </script>
# <script id="footable-js" src="https://www.police.lk/wp-content/plugins/ninja-tables/public/libs/footable/js/footable.min.js?ver=3.1.5"></script>
# <script id="footable_init-js-extra">
# var ninja_footables = {"ajax_url":"https:\/\/www.police.lk\/wp-admin\/admin-ajax.php","tables":[],"ninja_version":"4.2.3","i18n":{"search_in":"Search in","search":"Search","empty_text":"No Result Found"},"ninja_table_public_nonce":"bb1158ced2","pro_version":"4.3.4"};
# </script>
# <script id="footable_init-js" src="https://www.police.lk/wp-content/plugins/ninja-tables/assets/js/ninja-tables-footable.3.1.0.js?ver=4.2.3"></script>
# </body>
# </html>
