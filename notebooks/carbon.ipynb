# %%
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

# %%
Image.open(r"C:/Users/Anoban/Downloads/parts-of-plant.jpg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=800x1059>

# %%
fig, axes = plt.subplots()
fig.set_size_inches(20, 8)
axes.bar(np.arange(500, -1000, step=-100))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 3
#       1 fig, axes = plt.subplots()
#       2 fig.set_size_inches(20, 8)
# ----> 3 axes.bar(np.arange(500, -1000, step=-100))
#
# File C:\Program Files\Python313\Lib\site-packages\matplotlib\__init__.py:1524, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1521 @functools.wraps(func)
#    1522 def inner(ax, *args, data=None, **kwargs):
#    1523     if data is None:
# -> 1524         return func(
#    1525             ax,
#    1526             *map(cbook.sanitize_sequence, args),
#    1527             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1529     bound = new_sig.bind(ax, *args, **kwargs)
#    1530     auto_label = (bound.arguments.get(label_namer)
#    1531                   or bound.kwargs.get(label_namer))
#
# ...
