# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
os.listdir();

# %%
alcohol_nz_2022 = pd.read_csv("./alcohol-available-for-consumption-year-ended-december-2022.csv")

# %%
alcohol_nz_2022.isna().sum(axis = 0)
# Out:
# Unnamed: 0              0
# Unnamed: 1              0
# Series_reference        0
# Period                  0
# Data_value              5
# STATUS                  0
# UNITS                   0
# MAGNTUDE                0
# Subject                 0
# Group                   0
# Series_title_1          0
# Series_title_2      13565
# Series_title_3      13565
# Series_title_4      13565
# Series_title_5      13565
# dtype: int64

# %%
alcohol_nz_2022.drop(["Series_title_2", "Series_title_3", "Series_title_4", "Series_title_5"], axis = 1, inplace = True)

# %%
alcohol_nz_2022.isna().sum(axis = 0)
# Out:
# Unnamed: 0          0
# Unnamed: 1          0
# Series_reference    0
# Period              0
# Data_value          5
# STATUS              0
# UNITS               0
# MAGNTUDE            0
# Subject             0
# Group               0
# Series_title_1      0
# dtype: int64

# %%
alcohol_nz_2022
# Out:
#        Unnamed: 0 Unnamed: 1 Series_reference   Period  Data_value  \
# 0            1935        Dec          ALCA.S1  1935.12   51.100000
# 1            1936        Dec          ALCA.S1  1936.12   58.700000
# 2            1937        Dec          ALCA.S1  1937.12   68.700000
# 3            1938        Dec          ALCA.S1  1938.12   78.100000
# 4            1939        Dec          ALCA.S1  1939.12   79.200000
# ...           ...        ...              ...      ...         ...
# 13560        2021        Dec        ALCQ.SAZZ  2021.12  156.231872
# 13561        2022        Mar        ALCQ.SAZZ  2022.03  114.485861
# 13562        2022        Jun        ALCQ.SAZZ  2022.06  110.033064
# 13563        2022        Sep        ALCQ.SAZZ  2022.09  121.087105
# 13564        2022        Dec        ALCQ.SAZZ  2022.12  152.187695
#
#             STATUS   UNITS  MAGNTUDE                                  Subject  \
# 0            FINAL  Litres         6  Alcohol Available for Consumption - ALC
# 1            FINAL  Litres         6  Alcohol Available for Consumption - ALC
# 2            FINAL  Litres         6  Alcohol Available for Consumption - ALC
# 3            FINAL  Litres         6  Alcohol Available for Consumption - ALC
# 4            FINAL  Litres         6  Alcohol Available for Consumption - ALC
# ...            ...     ...       ...                                      ...
# 13560        FINAL  Litres         6  Alcohol Available for Consumption - ALC
# 13561        FINAL  Litres         6  Alcohol Available for Consumption - ALC
# 13562        FINAL  Litres         6  Alcohol Available for Consumption - ALC
# 13563        FINAL  Litres         6  Alcohol Available for Consumption - ALC
# 13564  PROVISIONAL  Litres         6  Alcohol Available for Consumption - ALC
#
#                                  Group       Series_title_1
# 0      (DISC) Volume & Volume Per Head                 Beer
# 1      (DISC) Volume & Volume Per Head                 Beer
# 2      (DISC) Volume & Volume Per Head                 Beer
# 3      (DISC) Volume & Volume Per Head                 Beer
# 4      (DISC) Volume & Volume Per Head                 Beer
# ...                                ...                  ...
# 13560               Litres of Beverage  Total all beverages
# 13561               Litres of Beverage  Total all beverages
# 13562               Litres of Beverage  Total all beverages
# 13563               Litres of Beverage  Total all beverages
# 13564               Litres of Beverage  Total all beverages
#
# [13565 rows x 11 columns]

# %%
alcohol_nz_2022.Series_title_1.unique()
# Out:
# array(['Beer', 'Wine', 'Spirits', 'Beer Per Head', 'Wine Per Head',
#        'Spirits Per Head', 'Beer containing not more than 1.150% alcohol',
#        'Beer containing between 1.151% and 2.500% alc',
#        'Beer containing between 2.501% and 4.350% alc',
#        'Beer containing between 4.351% and 5.000% alc',
#        'Beer containing more than 5.00% alcohol', 'Total beer',
#        'Total spirits (proof litres)',
#        'Spirits containing not more than 23% alcohol',
#        'Spirits containing more than 23% alcohol', 'Total spirits',
#        'Table wine (disc. Sept 1999)', 'Fortified wine (disc. Sept 1999)',
#        'Total wine (disc. Sept 1999)',
#        'Grape wine containing not more than 14% alc.',
#        'Grape wine containing more than 14% alcohol',
#        'Other wine containing not more than 14% alc.',
#        'Other wine containing more than 14% alcohol',
#        'Total wine containing not more than 14% alc.',
#        'Total wine containing more than 14% alcohol', 'Total wine',
#        'Total N.Z. Population 15 Years and Over for Total Alcohol',
#        'Total N.Z. Population 18 Years and Over for Total Alcohol',
#        'Total N.Z. Population 20 Years and Over for Total Alcohol',
#        'Total N.Z. Population for Total Alcohol',
#        'Total N.Z. Population 15 Years and Over for Total Beer',
#        'Total N.Z. Population 18 Years and Over for Total Beer',
#        'Total N.Z. Population 20 Years and Over for Total Beer',
#        'Total N.Z. Population for Total Beer',
#        'Total N.Z. Population 15 Years and Over for Total Wine',
#        'Total N.Z. Population 18 Years and Over for Total Wine',
#        'Total N.Z. Population 20 Years and Over for Total Wine',
#        'Total N.Z. Population for Total Wine',
#        'Total N.Z. Population 15 Years and Over for Total Spirits',
#        'Total N.Z. Population 18 Years and Over for Total Spirits',
#        'Total N.Z. Population 20 Years and Over for Total Spirits',
#        'Total N.Z. Population for Total Spirits',
#        'Total N.Z. Population 15 Years and Over for Spirits containing not more than 23% alcohol',
#        'Total N.Z. Population 18 Years and Over for Spirits containing not more than 23% alcohol',
#        'Total N.Z. Population 20 Years and Over for Spirits containing not more than 23% alcohol',
#        'Total N.Z. Population for Spirits containing not more than 23% alcohol',
#        'Total N.Z. Population 15 Years and Over for Spirits containing more than 23% alcohol',
#        'Total N.Z. Population 18 Years and Over for Spirits containing more than 23% alcohol',
#        'Total N.Z. Population 20 Years and Over for Spirits containing more than 23% alcohol',
#        'Total N.Z. Population for Spirits containing more than 23% alcohol',
#        'Total all beverages'], dtype=object)

# %%
beer = alcohol_nz_2022.loc[alcohol_nz_2022.Series_title_1 == "Beer", :]

# %%
beer.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Series_reference', 'Period', 'Data_value',
#        'STATUS', 'UNITS', 'MAGNTUDE', 'Subject', 'Group', 'Series_title_1'],
#       dtype='object')

# %%
fig, axes = plt.subplots()
fig.set_size_inches(10, 10)

axes.scatter(beer.loc[:, "Unnamed: 0"], beer.loc[:, "Data_value"], s = beer.loc[:, "Data_value"], c = beer.loc[:, "Data_value"], edgecolor = "black")
axes.set_xlabel("Years")
axes.set_ylabel("Litres")
plt.show()

# %%
alcohol_nz_2022.groupby("Series_title_1").apply(lambda gp: gp.shape)
# Out:
# Series_title_1
# Beer                                                                                         (47, 11)
# Beer Per Head                                                                                (47, 11)
# Beer containing between 1.151% and 2.500% alc                                               (362, 11)
# Beer containing between 2.501% and 4.350% alc                                               (362, 11)
# Beer containing between 4.351% and 5.000% alc                                               (362, 11)
# Beer containing more than 5.00% alcohol                                                     (362, 11)
# Beer containing not more than 1.150% alcohol                                                (362, 11)
# Fortified wine (disc. Sept 1999)                                                            (254, 11)
# Grape wine containing more than 14% alcohol                                                 (478, 11)
# Grape wine containing not more than 14% alc.                                                (478, 11)
# Other wine containing more than 14% alcohol                                                 (478, 11)
# Other wine containing not more than 14% alc.                                                (478, 11)
# Spirits                                                                                      (47, 11)
# Spirits Per Head                                                                             (47, 11)
# Spirits containing more than 23% alcohol                                                    (478, 11)
# Spirits containing not more than 23% alcohol                                                (478, 11)
# Table wine (disc. Sept 1999)                                                                (254, 11)
# Total N.Z. Population 15 Years and Over for Spirits containing more than 23% alcohol        (149, 11)
# Total N.Z. Population 15 Years and Over for Spirits containing not more than 23% alcohol    (149, 11)
# Total N.Z. Population 15 Years and Over for Total Alcohol                                   (299, 11)
# Total N.Z. Population 15 Years and Over for Total Beer                                      (151, 11)
# Total N.Z. Population 15 Years and Over for Total Spirits                                   (149, 11)
# Total N.Z. Population 15 Years and Over for Total Wine                                      (149, 11)
# Total N.Z. Population 18 Years and Over for Spirits containing more than 23% alcohol        (149, 11)
# Total N.Z. Population 18 Years and Over for Spirits containing not more than 23% alcohol    (149, 11)
# Total N.Z. Population 18 Years and Over for Total Alcohol                                   (301, 11)
# Total N.Z. Population 18 Years and Over for Total Beer                                      (149, 11)
# Total N.Z. Population 18 Years and Over for Total Spirits                                   (149, 11)
# Total N.Z. Population 18 Years and Over for Total Wine                                      (149, 11)
# Total N.Z. Population 20 Years and Over for Spirits containing more than 23% alcohol        (149, 11)
# Total N.Z. Population 20 Years and Over for Spirits containing not more than 23% alcohol    (149, 11)
# Total N.Z. Population 20 Years and Over for Total Alcohol                                   (301, 11)
# Total N.Z. Population 20 Years and Over for Total Beer                                      (149, 11)
# Total N.Z. Population 20 Years and Over for Total Spirits                                   (149, 11)
# Total N.Z. Population 20 Years and Over for Total Wine                                      (149, 11)
# Total N.Z. Population for Spirits containing more than 23% alcohol                          (149, 11)
# Total N.Z. Population for Spirits containing not more than 23% alcohol                      (149, 11)
# Total N.Z. Population for Total Alcohol                                                     (301, 11)
# Total N.Z. Population for Total Beer                                                        (149, 11)
# Total N.Z. Population for Total Spirits                                                     (149, 11)
# Total N.Z. Population for Total Wine                                                        (149, 11)
# Total all beverages                                                                         (635, 11)
# Total beer                                                                                  (612, 11)
# Total spirits                                                                               (665, 11)
# Total spirits (proof litres)                                                                (313, 11)
# Total wine                                                                                  (478, 11)
# Total wine (disc. Sept 1999)                                                                (254, 11)
# Total wine containing more than 14% alcohol                                                 (478, 11)
# Total wine containing not more than 14% alc.                                                (478, 11)
# Wine                                                                                         (47, 11)
# Wine Per Head                                                                                (47, 11)
# dtype: object

# %%
nz_immig = pd.read_csv("./international-migration-september-2023-citizenship-by-visa-by-country-of-last-permanent-residence.csv")

# %%
nz_immig.columns
# Out:
# Index(['year_month', 'month_of_release', 'passenger_type', 'direction',
#        'citizenship', 'visa', 'country_of_residence', 'estimate',
#        'standard_error', 'status'],
#       dtype='object')

# %%
nz_immig.country_of_residence.unique()
# Out:
# array(['Afghanistan', 'Africa and the Middle East', 'Albania', 'Algeria',
#        'Andorra', 'Angola', 'Anguilla', 'Antarctica',
#        'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba', 'Asia',
#        'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain',
#        'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin',
#        'Bermuda', 'Bhutan', 'Bolivia', 'Bosnia and Herzegovina',
#        'Botswana', 'Brazil', 'British Indian Ocean Territory',
#        'Brunei Darussalam', 'Bulgaria', 'Burkina Faso', 'Burundi',
#        'Cabo Verde', 'Cambodia', 'Cameroon', 'Canada', 'Cayman Islands',
#        'Chad', 'Chile', "China, People's Republic of", 'Christmas Island',
#        'Cocos (Keeling) Islands', 'Colombia', 'Comoros', 'Congo',
#        'Congo, the Democratic Republic of the', 'Cook Islands',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Curacao',
#        'Cyprus', 'Czech Republic (to Sep 2018), Czechia (from Oct 2018)',
#        'Czechoslovakia', 'Denmark', 'Djibouti', 'Dominica',
#        'Dominican Republic', 'East Timor', 'Ecuador', 'Egypt',
#        'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Estonia',
#        'Ethiopia', 'Europe', 'Faeroe Islands', 'Falkland Islands', 'Fiji',
#        'Finland', 'France', 'French Guiana', 'French Polynesia', 'Gabon',
#        'Gambia', 'Gaza Strip/Palestine/West Bank', 'Georgia', 'Germany',
#        'Ghana', 'Gibraltar', 'Greece', 'Greenland', 'Grenada',
#        'Guadeloupe', 'Guam', 'Guatemala', 'Guinea', 'Guinea-Bissau',
#        'Guyana', 'Haiti', 'Honduras',
#        'Hong Kong (Special Administrative Region)', 'Hungary', 'Iceland',
#        'India', 'Indonesia', 'Iran', 'Iraq', 'Ireland', 'Israel', 'Italy',
#        'Jamaica', 'Japan', 'Jordan', 'Kazakhstan', 'Kenya', 'Kiribati',
#        "Korea, Democratic People's Republic of", 'Korea, Republic of',
#        'Kosovo', 'Kuwait', 'Kyrgyzstan', 'Laos', 'Latvia', 'Lebanon',
#        'Lesotho', 'Liberia', 'Libya', 'Liechtenstein', 'Lithuania',
#        'Luxembourg', 'Macau (Special Administrative Region)',
#        'Madagascar', 'Malawi', 'Malaysia', 'Maldives', 'Mali', 'Malta',
#        'Marshall Islands', 'Martinique', 'Mauritania', 'Mauritius',
#        'Mexico', 'Micronesia, Federated States of', 'Moldova', 'Monaco',
#        'Mongolia', 'Montenegro', 'Montserrat', 'Morocco', 'Mozambique',
#        'Myanmar', 'Namibia', 'Nauru', 'Nepal', 'Netherlands',
#        'Netherlands Antilles', 'New Caledonia', 'New Zealand',
#        'Nicaragua', 'Niger', 'Nigeria', 'Niue', 'Norfolk Island',
#        'North Macedonia', 'Northern Mariana Islands', 'Norway',
#        'Not Stated', 'Oceania and Antarctica', 'Oman', 'Pakistan',
#        'Palau', 'Panama', 'Papua New Guinea', 'Paraguay', 'Peru',
#        'Philippines', 'Pitcairn', 'Poland', 'Portugal', 'Puerto Rico',
#        'Qatar', 'Reunion', 'Romania', 'Russia', 'Rwanda', 'Samoa',
#        'Samoa, American', 'San Marino', 'Saudi Arabia', 'Senegal',
#        'Serbia', 'Seychelles', 'Sierra Leone', 'Singapore', 'Slovakia',
#        'Slovenia', 'Solomon Islands', 'Somalia', 'South Africa',
#        'South Georgia and the South Sandwich Islands', 'South Sudan',
#        'Spain', 'Sri Lanka', 'St Helena', 'St Kitts and Nevis',
#        'St Lucia', 'St Maarten (Dutch Part)', 'St Pierre and Miquelon',
#        'St Vincent and the Grenadines', 'Sudan', 'Suriname',
#        'Swaziland (to Sep 2018), Eswatini (from Oct 2018)', 'Sweden',
#        'Switzerland', 'Syria', 'TOTAL', 'Taiwan', 'Tajikistan',
#        'Tanzania', 'Thailand', 'The Americas', 'Timor-Leste', 'Togo',
#        'Tokelau', 'Tonga', 'Trinidad and Tobago', 'Tunisia', 'Turkey',
#        'Turkmenistan', 'Turks and Caicos Islands', 'Tuvalu', 'Uganda',
#        'Ukraine', 'United Arab Emirates', 'United Kingdom',
#        'United States Minor Outlying Islands', 'United States of America',
#        'Uruguay', 'Uzbekistan', 'Vanuatu', 'Vatican City State',
#        'Venezuela', 'Viet Nam', 'Virgin Islands, British',
#        'Virgin Islands, United States', 'Wallis and Futuna',
#        'Western Sahara', 'Yemen',
#        'Yugoslavia (to Aug 2003), Serbia and Montenegro (from Sep 2003)',
#        'Zambia', 'Zimbabwe', 'Central African Republic', 'Mayotte',
#        'Sao Tome and Principe'], dtype=object)

# %%
np.unique(nz_immig.country_of_residence, return_counts = True)
# Out:
# (array(['Afghanistan', 'Africa and the Middle East', 'Albania', 'Algeria',
#         'Andorra', 'Angola', 'Anguilla', 'Antarctica',
#         'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba', 'Asia',
#         'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain',
#         'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin',
#         'Bermuda', 'Bhutan', 'Bolivia', 'Bosnia and Herzegovina',
#         'Botswana', 'Brazil', 'British Indian Ocean Territory',
#         'Brunei Darussalam', 'Bulgaria', 'Burkina Faso', 'Burundi',
#         'Cabo Verde', 'Cambodia', 'Cameroon', 'Canada', 'Cayman Islands',
#         'Central African Republic', 'Chad', 'Chile',
#         "China, People's Republic of", 'Christmas Island',
#         'Cocos (Keeling) Islands', 'Colombia', 'Comoros', 'Congo',
#         'Congo, the Democratic Republic of the', 'Cook Islands',
#         'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Curacao',
#         'Cyprus', 'Czech Republic (to Sep 2018), Czechia (from Oct 2018)',
#         'Czechoslovakia', 'Denmark', 'Djibouti', 'Dominica',
#         'Dominican Republic', 'East Timor', 'Ecuador', 'Egypt',
#         'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Estonia',
#         'Ethiopia', 'Europe', 'Faeroe Islands', 'Falkland Islands', 'Fiji',
#         'Finland', 'France', 'French Guiana', 'French Polynesia', 'Gabon',
#         'Gambia', 'Gaza Strip/Palestine/West Bank', 'Georgia', 'Germany',
#         'Ghana', 'Gibraltar', 'Greece', 'Greenland', 'Grenada',
#         'Guadeloupe', 'Guam', 'Guatemala', 'Guinea', 'Guinea-Bissau',
#         'Guyana', 'Haiti', 'Honduras',
#         'Hong Kong (Special Administrative Region)', 'Hungary', 'Iceland',
#         'India', 'Indonesia', 'Iran', 'Iraq', 'Ireland', 'Israel', 'Italy',
#         'Jamaica', 'Japan', 'Jordan', 'Kazakhstan', 'Kenya', 'Kiribati',
#         "Korea, Democratic People's Republic of", 'Korea, Republic of',
#         'Kosovo', 'Kuwait', 'Kyrgyzstan', 'Laos', 'Latvia', 'Lebanon',
#         'Lesotho', 'Liberia', 'Libya', 'Liechtenstein', 'Lithuania',
#         'Luxembourg', 'Macau (Special Administrative Region)',
#         'Madagascar', 'Malawi', 'Malaysia', 'Maldives', 'Mali', 'Malta',
#         'Marshall Islands', 'Martinique', 'Mauritania', 'Mauritius',
#         'Mayotte', 'Mexico', 'Micronesia, Federated States of', 'Moldova',
#         'Monaco', 'Mongolia', 'Montenegro', 'Montserrat', 'Morocco',
#         'Mozambique', 'Myanmar', 'Namibia', 'Nauru', 'Nepal',
#         'Netherlands', 'Netherlands Antilles', 'New Caledonia',
#         'New Zealand', 'Nicaragua', 'Niger', 'Nigeria', 'Niue',
#         'Norfolk Island', 'North Macedonia', 'Northern Mariana Islands',
#         'Norway', 'Not Stated', 'Oceania and Antarctica', 'Oman',
#         'Pakistan', 'Palau', 'Panama', 'Papua New Guinea', 'Paraguay',
#         'Peru', 'Philippines', 'Pitcairn', 'Poland', 'Portugal',
#         'Puerto Rico', 'Qatar', 'Reunion', 'Romania', 'Russia', 'Rwanda',
#         'Samoa', 'Samoa, American', 'San Marino', 'Sao Tome and Principe',
#         'Saudi Arabia', 'Senegal', 'Serbia', 'Seychelles', 'Sierra Leone',
#         'Singapore', 'Slovakia', 'Slovenia', 'Solomon Islands', 'Somalia',
#         'South Africa', 'South Georgia and the South Sandwich Islands',
#         'South Sudan', 'Spain', 'Sri Lanka', 'St Helena',
#         'St Kitts and Nevis', 'St Lucia', 'St Maarten (Dutch Part)',
#         'St Pierre and Miquelon', 'St Vincent and the Grenadines', 'Sudan',
#         'Suriname', 'Swaziland (to Sep 2018), Eswatini (from Oct 2018)',
#         'Sweden', 'Switzerland', 'Syria', 'TOTAL', 'Taiwan', 'Tajikistan',
#         'Tanzania', 'Thailand', 'The Americas', 'Timor-Leste', 'Togo',
#         'Tokelau', 'Tonga', 'Trinidad and Tobago', 'Tunisia', 'Turkey',
#         'Turkmenistan', 'Turks and Caicos Islands', 'Tuvalu', 'Uganda',
#         'Ukraine', 'United Arab Emirates', 'United Kingdom',
#         'United States Minor Outlying Islands', 'United States of America',
#         'Uruguay', 'Uzbekistan', 'Vanuatu', 'Vatican City State',
#         'Venezuela', 'Viet Nam', 'Virgin Islands, British',
#         'Virgin Islands, United States', 'Wallis and Futuna',
#         'Western Sahara', 'Yemen',
#         'Yugoslavia (to Aug 2003), Serbia and Montenegro (from Sep 2003)',
#         'Zambia', 'Zimbabwe'], dtype=object),
#  array([1791, 4064,  383,  512,  229,  345,  128,  189,  243, 2540,  281,
#          114, 4124, 3838, 2532,  347,  355, 1940, 2411,  360,  737, 2456,
#          169,  105,  878,  467,  827,  422, 1342, 3190,   12, 1918, 1302,
#          126,  141,   35, 3037,  310, 3786,  899,    8,  194, 2825, 4003,
#           86,   16, 2381,   48,  229,  135, 2112,  739,  104, 1330,  398,
#           61, 1004, 2179,  387, 2454,   87,  155,  263,   62, 1252, 2410,
#          281,   93,  249,  777, 1627, 4122,  104,  355, 3862, 1861, 3462,
#           53, 1898,  213,  201,  463,  330, 3641, 1374,  193, 1673,   27,
#          142,  118,  479,  533,  201,    8,  280,   58,  262, 3600, 1890,
#          842, 3851, 3602, 2897, 1923, 3359, 2401, 3023,  678, 3761, 2011,
#         1330, 2005, 2257,   44, 3754,  219, 2019,  455, 1276, 1044, 1314,
#          109,  200,  462,   60,  726,  729, 1474,  215,  624, 3732, 1064,
#          246,  897,  482,   61,   36, 1361,   10, 2636,  234,  407,  277,
#          913,  137,   30,  726,  425, 1487, 1032,  558, 2364, 3351,  158,
#         2073, 3137,  268,  148, 1784, 1502,  815, 1173,  204, 2066, 4084,
#         4110, 2257, 2963,  253,  617, 2761,  395, 1971, 3852,  262, 2041,
#         1546,  127, 2415,  305, 1955, 3441,  298, 3754, 1834,   39,    4,
#         3292,  181, 1184,  471,  196, 3795, 1297,  969, 1837,  815, 3689,
#           12,   91, 3035, 3123,   48,  121,  185,   70,   40,  148,  765,
#          184,  362, 2841, 3077, 1017, 4128, 3438,  196, 1273, 3763, 4121,
#          913,  107, 1103, 3768,  570,  323, 2484,   62,  213, 1842,  877,
#         2295, 3477, 4052,   51, 4089, 1602,  772, 2354,   16,  883, 3457,
#          254,   40,  257,   24,  373,  172, 1437, 2425], dtype=int64))

# %%
fig, axes = plt.subplots()
fig.set_size_inches(10, 50)

axes.hist(nz_immig.country_of_residence, rwidth = 0.2, color = "grey", orientation = "horizontal")
axes.grid(axis = "x")
axes.set_axisbelow(True)
# for ytlab in axes.get_yticklabels():
#   ytlab.set_rotation(90)

# apply(lambda xtlab: xtlab.set_rotation(90), axes.get_xticklabels())
# won't work because with map() we need to capture the output and use it.
# in-place modifications seem not to be supported

axes.set_xscale("log")
axes.set_ylabel("Country of origin")
axes.set_xlabel("Count")
plt.show()

# %%
[(x, y) for (x, y, _) in axes.get_xticklabels()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 [(x, y) for (x, y, _) in axes.get_xticklabels()]
#
# Cell In[64], line 1, in <listcomp>(.0)
# ----> 1 [(x, y) for (x, y, _) in axes.get_xticklabels()]
#
# TypeError: cannot unpack non-iterable Text object

# %%
dir(axes.get_xticklabels()[0])
# Out:
# ['_PROPERTIES_EXCLUDED_FROM_SET',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_agg_filter',
#  '_alias_map',
#  '_alpha',
#  '_animated',
#  '_antialiased',
#  '_axes',
#  '_bbox_patch',
#  '_callbacks',
#  '_char_index_at',
#  '_charsize_cache',
#  '_clipon',
#  '_clippath',
#  '_cm_set',
#  '_color',
#  '_different_canvas',
#  '_fontproperties',
#  '_fully_clipped_to_axes',
#  '_get_dist_to_box',
#  '_get_layout',
#  '_get_multialignment',
#  '_get_rendered_text_width',
#  '_get_wrap_line_width',
#  '_get_wrapped_text',
#  '_get_xy_display',
#  '_gid',
#  '_horizontalalignment',
#  '_in_layout',
#  '_internal_update',
#  '_label',
#  '_linespacing',
#  '_mouseover',
#  '_multialignment',
#  '_parse_math',
#  '_path_effects',
#  '_picker',
#  '_preprocess_math',
#  '_rasterized',
#  '_remove_method',
#  '_renderer',
#  '_reset_visual_defaults',
#  '_rotation',
#  '_rotation_mode',
#  '_set_alpha_for_array',
#  '_set_gc_clip',
#  '_sketch',
#  '_snap',
#  '_stale',
#  '_sticky_edges',
#  '_text',
#  '_transform',
#  '_transformSet',
#  '_transform_rotates_text',
#  '_update_clip_properties',
#  '_update_props',
#  '_update_set_signature_and_docstring',
#  '_url',
#  '_usetex',
#  '_verticalalignment',
#  '_visible',
#  '_wrap',
#  '_x',
#  '_y',
#  'add_callback',
#  'axes',
#  'clipbox',
#  'contains',
#  'convert_xunits',
#  'convert_yunits',
#  'draw',
#  'figure',
#  'findobj',
#  'format_cursor_data',
#  'get_agg_filter',
#  'get_alpha',
#  'get_animated',
#  'get_antialiased',
#  'get_bbox_patch',
#  'get_c',
#  'get_children',
#  'get_clip_box',
#  'get_clip_on',
#  'get_clip_path',
#  'get_color',
#  'get_cursor_data',
#  'get_family',
#  'get_figure',
#  'get_font',
#  'get_font_properties',
#  'get_fontfamily',
#  'get_fontname',
#  'get_fontproperties',
#  'get_fontsize',
#  'get_fontstyle',
#  'get_fontvariant',
#  'get_fontweight',
#  'get_gid',
#  'get_ha',
#  'get_horizontalalignment',
#  'get_in_layout',
#  'get_label',
#  'get_math_fontfamily',
#  'get_mouseover',
#  'get_name',
#  'get_parse_math',
#  'get_path_effects',
#  'get_picker',
#  'get_position',
#  'get_rasterized',
#  'get_rotation',
#  'get_rotation_mode',
#  'get_size',
#  'get_sketch_params',
#  'get_snap',
#  'get_stretch',
#  'get_style',
#  'get_text',
#  'get_tightbbox',
#  'get_transform',
#  'get_transform_rotates_text',
#  'get_transformed_clip_path_and_affine',
#  'get_unitless_position',
#  'get_url',
#  'get_usetex',
#  'get_va',
#  'get_variant',
#  'get_verticalalignment',
#  'get_visible',
#  'get_weight',
#  'get_window_extent',
#  'get_wrap',
#  'get_zorder',
#  'have_units',
#  'is_transform_set',
#  'mouseover',
#  'pchanged',
#  'pick',
#  'pickable',
#  'properties',
#  'remove',
#  'remove_callback',
#  'set',
#  'set_agg_filter',
#  'set_alpha',
#  'set_animated',
#  'set_antialiased',
#  'set_backgroundcolor',
#  'set_bbox',
#  'set_c',
#  'set_clip_box',
#  'set_clip_on',
#  'set_clip_path',
#  'set_color',
#  'set_family',
#  'set_figure',
#  'set_font',
#  'set_font_properties',
#  'set_fontfamily',
#  'set_fontname',
#  'set_fontproperties',
#  'set_fontsize',
#  'set_fontstretch',
#  'set_fontstyle',
#  'set_fontvariant',
#  'set_fontweight',
#  'set_gid',
#  'set_ha',
#  'set_horizontalalignment',
#  'set_in_layout',
#  'set_label',
#  'set_linespacing',
#  'set_ma',
#  'set_math_fontfamily',
#  'set_mouseover',
#  'set_multialignment',
#  'set_name',
#  'set_parse_math',
#  'set_path_effects',
#  'set_picker',
#  'set_position',
#  'set_rasterized',
#  'set_rotation',
#  'set_rotation_mode',
#  'set_size',
#  'set_sketch_params',
#  'set_snap',
#  'set_stretch',
#  'set_style',
#  'set_text',
#  'set_transform',
#  'set_transform_rotates_text',
#  'set_url',
#  'set_usetex',
#  'set_va',
#  'set_variant',
#  'set_verticalalignment',
#  'set_visible',
#  'set_weight',
#  'set_wrap',
#  'set_x',
#  'set_y',
#  'set_zorder',
#  'stale',
#  'stale_callback',
#  'sticky_edges',
#  'update',
#  'update_bbox_position_size',
#  'update_from',
#  'zorder']

# %%
axes.get_xticklabels()[0]._label
# Out:
# ''

# %%
nz_immig.country_of_residence.value_counts()
# Out:
# country_of_residence
# TOTAL                                           4128
# Asia                                            4124
# Europe                                          4122
# The Americas                                    4121
# Oceania and Antarctica                          4110
#                                                 ...
# South Georgia and the South Sandwich Islands      12
# Mayotte                                           10
# Guinea-Bissau                                      8
# Central African Republic                           8
# Sao Tome and Principe                              4
# Name: count, Length: 250, dtype: int64

# %%
fig, axes = plt.subplots()
fig.set_size_inches(50, 30)

axes.bar(nz_immig.country_of_residence.value_counts().index, nz_immig.country_of_residence.value_counts().values, color = "brown")
for xtlab in axes.get_xticklabels():
    xtlab.set_rotation(90)
axes.grid(axis = "y")
axes.set_axisbelow(True)
axes.set_xlabel("Country of origin")
axes.set_ylabel("Count")
# plt.show()
plt.savefig("./nz_immigrants.jpeg", format = "jpg", dpi = 1000)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[123], line 12
#      10 axes.set_ylabel("Count")
#      11 # plt.show()
# ---> 12 plt.savefig("./nz_immigrants.jpeg", format = "jpg", dpi = 1000)
#
# File C:\Program Files\Python311\Lib\site-packages\matplotlib\pyplot.py:1119, in savefig(*args, **kwargs)
#    1116 fig = gcf()
#    1117 # savefig default implementation has no return, so mypy is unhappy
#    1118 # presumably this is here because subclasses can return?
# -> 1119 res = fig.savefig(*args, **kwargs)  # type: ignore[func-returns-value]
#    1120 fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1121 return res
#
# File C:\Program Files\Python311\Lib\site-packages\matplotlib\figure.py:3390, in Figure.savefig(self, fname, transparent, **kwargs)
#    3388     for ax in self.axes:
#    3389         _recursively_make_axes_transparent(stack, ax)
# -> 3390 self.canvas.print_figure(fname, **kwargs)
#
# File C:\Program Files\Python311\Lib\site-packages\matplotlib\backend_bases.py:2193, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2189 try:
#    2190     # _get_renderer may change the figure dpi (as vector formats
#    2191     # force the figure dpi to 72), so we need to set it again here.
#    2192     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2193         result = print_method(
#    2194             filename,
#    2195             facecolor=facecolor,
#    2196             edgecolor=edgecolor,
#    2197             orientation=orientation,
#    2198             bbox_inches_restore=_bbox_inches_restore,
#    2199             **kwargs)
#    2200 finally:
#    2201     if bbox_inches and restore_bbox:
#
# File C:\Program Files\Python311\Lib\site-packages\matplotlib\backend_bases.py:2043, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2039     optional_kws = {  # Passed by print_figure for other renderers.
#    2040         "dpi", "facecolor", "edgecolor", "orientation",
#    2041         "bbox_inches_restore"}
#    2042     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2043     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2044         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2045 else:  # Let third-parties do as they see fit.
#    2046     print_method = meth
#
# File C:\Program Files\Python311\Lib\site-packages\matplotlib\backends\backend_agg.py:514, in FigureCanvasAgg.print_jpg(self, filename_or_obj, metadata, pil_kwargs)
#     509 def print_jpg(self, filename_or_obj, *, metadata=None, pil_kwargs=None):
#     510     # savefig() has already applied savefig.facecolor; we now set it to
#     511     # white to make imsave() blend semi-transparent figures against an
#     512     # assumed white background.
#     513     with mpl.rc_context({"savefig.facecolor": "white"}):
# --> 514         self._print_pil(filename_or_obj, "jpeg", pil_kwargs, metadata)
#
# File C:\Program Files\Python311\Lib\site-packages\matplotlib\backends\backend_agg.py:446, in FigureCanvasAgg._print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     441 """
#     442 Draw the canvas, then save it using `.image.imsave` (to which
#     443 *pil_kwargs* and *metadata* are forwarded).
#     444 """
#     445 FigureCanvasAgg.draw(self)
# --> 446 mpl.image.imsave(
#     447     filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     448     dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File C:\Program Files\Python311\Lib\site-packages\matplotlib\image.py:1651, in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1649     facecolor = mpl.rcParams["figure.facecolor"]
#    1650 color = tuple(int(x * 255) for x in mcolors.to_rgb(facecolor))
# -> 1651 background = PIL.Image.new("RGB", pil_shape, color)
#    1652 background.paste(image, image)
#    1653 image = background
#
# File C:\Program Files\Python311\Lib\site-packages\PIL\Image.py:2939, in new(mode, size, color)
#    2937     im.palette = ImagePalette.ImagePalette()
#    2938     color = im.palette.getcolor(color)
# -> 2939 return im._new(core.fill(mode, size, color))
#
# MemoryError:

# %%
import gc

# %%
gc.collect(2)
# Out:
# 0
