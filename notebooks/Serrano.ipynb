# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.array((1, -5, 2, 0,-3 ))

# %%
(x * x).sum()
# Out:
# 39

# %%
x_0 = (0, 1)
x_1 = (0, 0)
y_0 = (0, 0)
y_1 = (0, -1)
z_0 = (0, 7)
z_1 = (0, 2)

# %%
fig = plt.figure(figsize = (10, 10))
axes = fig.add_subplot(projection = "3d")
axes.plot(x_0, y_0, z_0)
axes.plot(x_1, y_1, z_1)
axes.set_xlim(-1, 2)
axes.set_ylim(-1, 10)
axes.set_zlim(-2, 4)
plt.show()
