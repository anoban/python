# %%
# !python --version
# Out:
# Python 3.13.12

# %%
import os
import re

# %%
files = [source for source in os.listdir(r"./../../cpp20/") if (source.endswith(".cpp") or source.endswith(".hpp"))]

# %%
contents = dict.fromkeys(files)

for file in files:
    with open(file=f"./../../cpp20/{file}", mode="rt") as fp:
        contents[file] = fp.read()

# %%
for (file, text) in contents.items():
    if r"wprintf(L" in text:
        print(file)
# Out:
# movsem_01.cpp
