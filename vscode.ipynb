# %%
settings = sort_settings(parse_settings(open_vscode_settings_dot_json(r"C:\Users\Anoban\AppData\Roaming\Code\User\settings.json")))

# %%
settings
# Out:
# {'C_Cpp.autocompleteAddParentheses': True,
#  'C_Cpp.caseSensitiveFileSupport': 'enabled',
#  'C_Cpp.clang_format_style': '',
#  'C_Cpp.codeAnalysis.clangTidy.args': [],
#  'C_Cpp.codeAnalysis.clangTidy.codeAction.showClear': 'None',
#  'C_Cpp.codeAnalysis.clangTidy.codeAction.showDisable': False,
#  'C_Cpp.codeAnalysis.clangTidy.enabled': True,
#  'C_Cpp.codeFolding': 'disabled',
#  'C_Cpp.copilotHover': 'disabled',
#  'C_Cpp.default.cStandard': 'c23',
#  'C_Cpp.default.compilerArgs': ['/C',
#   '/DDEBUG',
#   '/D_DEBUG',
#   '/D__STDC_WANT_SECURE_LIB__',
#   '/I./',
#   '/I./include/',
#   '/Zc:__cplusplus',
#   '/Zc:preprocessor',
#   '/TP',
#   '/Wall',
#   '/Od',
#   '/std:c++20'],
#  'C_Cpp.default.cppStandard': 'c++20',
#  'C_Cpp.default.includePath': ['C:\\Program Files\\NVIDIA GPU Computing Toolkit\\CUDA\\v12.6\\include\\'],
#  'C_Cpp.default.intelliSenseMode': 'msvc-x64',
#  'C_Cpp.doxygen.generateOnType': False,
#  'C_Cpp.errorSquiggles': 'enabled',
# ...

# %%
# if the value is itself a dict, sort it too

for key in sorted(settings):
    if isinstance(settings.get(key), dict):
        print({k: settings.get(key).get(k) for k in sorted(settings.get(key))})
# Out:
# {'editor.semanticHighlighting.enabled': True, 'editor.suggest.insertMode': 'replace', 'editor.wordBasedSuggestions': 'allDocuments'}
# {'editor.defaultFormatter': 'charliermarsh.ruff', 'editor.formatOnSave': True}
# {'sound': 'on'}
# {'source.fixAll': 'explicit', 'source.organizeImports': 'explicit'}
# {'*.c': 'c', '*.cu': 'cuda-cpp', '*.cuh': 'cuda-cpp', '*.h': 'c', '.clang-format': 'yaml', '.clang-tidy': 'yaml', '.clangd': 'yaml'}
# ...
